# %% [markdown]
# # Feature Selection

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()
# %matplotlib inline

# %%
cur_path = '/Users/sonalichaudhari/Desktop/ADS_Project/Data'
df = pd.read_csv(open(cur_path+'/Final_Data.csv','rU'), encoding='utf-8')

# %%
df.shape
# Out:
# (8006399, 22)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()
plt.figure(figsize = (30,20))
sns.set(font_scale = 2)
sns.heatmap(data=df.corr())
plt.show()
plt.gcf().clear()

# %%
df.corr()
# Out:
#                           Year  CRSDepTime  CRSArrTime  DestAirportID  \
# Year                  1.000000   -0.000446   -0.000709       0.006692
# CRSDepTime           -0.000446    1.000000    0.670336       0.034487
# CRSArrTime           -0.000709    0.670336    1.000000       0.023609
# DestAirportID         0.006692    0.034487    0.023609       1.000000
# Distance              0.005939   -0.008225    0.017714       0.079038
# Month                -0.229617   -0.001752   -0.005968      -0.001508
# DayofMonth            0.001208    0.000604   -0.000743      -0.000227
# DayOfWeek             0.000186    0.007597    0.006470       0.004914
# AirlineID            -0.003942    0.004178   -0.005746       0.002009
# Quarter              -0.236152   -0.001971   -0.005887      -0.001483
# FlightNum             0.011318    0.003377   -0.000396      -0.003268
# OriginAirportID       0.006752   -0.035766   -0.006634       0.018622
# CRSElapsedTime        0.009199   -0.013183    0.025312       0.086811
# DepTime               0.001063    0.955662    0.678065       0.034968
# DepDelayMinutes       0.021930    0.104932    0.087524       0.001590
# DepartureDelayGroups  0.022263    0.147760    0.123962       0.007820
# WheelsOff             0.001568    0.926984    0.690861       0.035842
# TaxiOut               0.032377    0.014113    0.035025       0.016820
# TaxiIn                0.012690   -0.040126    0.003029      -0.049374
# WheelsOn             -0.003899    0.621896    0.862731       0.023677
# ArrTime              -0.004006    0.593659    0.854840       0.022112
# ArrivalDelayGroups    0.025496    0.127549    0.110272       0.018356
# ActualElapsedTime     0.011668   -0.015018    0.025337       0.092996
# ArrDelayMinutes       0.023551    0.093004    0.081736       0.004308
#
#                       Distance     Month  DayofMonth  DayOfWeek  AirlineID  \
# Year                  0.005939 -0.229617    0.001208   0.000186  -0.003942
# CRSDepTime           -0.008225 -0.001752    0.000604   0.007597   0.004178
# CRSArrTime            0.017714 -0.005968   -0.000743   0.006470  -0.005746
# DestAirportID         0.079038 -0.001508   -0.000227   0.004914   0.002009
# Distance              1.000000  0.002331   -0.000050   0.018475   0.000856
# Month                 0.002331  1.000000    0.009722   0.002341   0.000628
# DayofMonth           -0.000050  0.009722    1.000000  -0.004577   0.000969
# DayOfWeek             0.018475  0.002341   -0.004577   1.000000   0.003244
# AirlineID             0.000856  0.000628    0.000969   0.003244   1.000000
# Quarter               0.002580  0.965495    0.010231   0.006522   0.000727
# FlightNum            -0.304774  0.004855    0.005176   0.035925   0.212817
# OriginAirportID       0.078709 -0.001498   -0.000211   0.005157   0.002244
# CRSElapsedTime        0.984799 -0.005744   -0.000231   0.016555   0.032479
# DepTime              -0.017189 -0.002439   -0.000309   0.006201  -0.001487
# DepDelayMinutes       0.013161 -0.000714   -0.008222  -0.000644   0.038847
# DepartureDelayGroups  0.028953  0.000490   -0.009122  -0.000454   0.017428
# WheelsOff            -0.028937 -0.003062   -0.000512   0.004727  -0.000750
# TaxiOut               0.074532 -0.000690   -0.001550  -0.018081   0.187052
# TaxiIn                0.111138  0.013967    0.000361   0.004147   0.076121
# WheelsOn              0.008150 -0.007057   -0.001519   0.005021  -0.009645
# ArrTime               0.004985 -0.006566   -0.001507   0.004676  -0.008096
# ArrivalDelayGroups   -0.009516  0.001664   -0.009574  -0.007010   0.025930
# ActualElapsedTime     0.973637 -0.004356   -0.000801   0.013515   0.037778
# ArrDelayMinutes       0.007168 -0.001643   -0.008875  -0.002899   0.046754
#
#                        Quarter       ...         DepDelayMinutes  \
# Year                 -0.236152       ...                0.021930
# CRSDepTime           -0.001971       ...                0.104932
# CRSArrTime           -0.005887       ...                0.087524
# DestAirportID        -0.001483       ...                0.001590
# Distance              0.002580       ...                0.013161
# Month                 0.965495       ...               -0.000714
# DayofMonth            0.010231       ...               -0.008222
# DayOfWeek             0.006522       ...               -0.000644
# AirlineID             0.000727       ...                0.038847
# Quarter               1.000000       ...                0.001198
# FlightNum             0.003721       ...                0.010466
# OriginAirportID      -0.001468       ...               -0.002849
# CRSElapsedTime       -0.005327       ...                0.018371
# DepTime              -0.002584       ...                0.139229
# DepDelayMinutes       0.001198       ...                1.000000
# DepartureDelayGroups  0.002370       ...                0.873470
# WheelsOff            -0.003215       ...                0.129487
# TaxiOut              -0.001242       ...                0.065710
# TaxiIn                0.014849       ...                0.018684
# WheelsOn             -0.007060       ...                0.029159
# ArrTime              -0.006550       ...                0.020741
# ArrivalDelayGroups    0.002641       ...                0.819736
# ActualElapsedTime    -0.004342       ...                0.021848
# ArrDelayMinutes       0.000025       ...                0.973221
#
#                       DepartureDelayGroups  WheelsOff   TaxiOut    TaxiIn  \
# Year                              0.022263   0.001568  0.032377  0.012690
# CRSDepTime                        0.147760   0.926984  0.014113 -0.040126
# CRSArrTime                        0.123962   0.690861  0.035025  0.003029
# DestAirportID                     0.007820   0.035842  0.016820 -0.049374
# Distance                          0.028953  -0.028937  0.074532  0.111138
# Month                             0.000490  -0.003062 -0.000690  0.013967
# DayofMonth                       -0.009122  -0.000512 -0.001550  0.000361
# DayOfWeek                        -0.000454   0.004727 -0.018081  0.004147
# AirlineID                         0.017428  -0.000750  0.187052  0.076121
# Quarter                           0.002370  -0.003215 -0.001242  0.014849
# FlightNum                        -0.001613   0.016069  0.042941 -0.060848
# OriginAirportID                  -0.004095  -0.036847 -0.025236  0.038612
# CRSElapsedTime                    0.033322  -0.027620  0.117268  0.137847
# DepTime                           0.197454   0.968873  0.022421 -0.035723
# DepDelayMinutes                   0.873470   0.129487  0.065710  0.018684
# DepartureDelayGroups              1.000000   0.186158  0.077780  0.014323
# WheelsOff                         0.186158   1.000000  0.046184 -0.033466
# TaxiOut                           0.077780   0.046184  1.000000  0.027420
# TaxiIn                            0.014323  -0.033466  0.027420  1.000000
# WheelsOn                          0.066147   0.669376  0.039235  0.003360
# ArrTime                           0.054945   0.639933  0.035979  0.005950
# ArrivalDelayGroups                0.916818   0.170498  0.262730  0.128127
# ActualElapsedTime                 0.037795  -0.025611  0.208406  0.194771
# ArrDelayMinutes                   0.837638   0.121107  0.183695  0.089304
#
#                       WheelsOn   ArrTime  ArrivalDelayGroups  \
# Year                 -0.003899 -0.004006            0.025496
# CRSDepTime            0.621896  0.593659            0.127549
# CRSArrTime            0.862731  0.854840            0.110272
# DestAirportID         0.023677  0.022112            0.018356
# Distance              0.008150  0.004985           -0.009516
# Month                -0.007057 -0.006566            0.001664
# DayofMonth           -0.001519 -0.001507           -0.009574
# DayOfWeek             0.005021  0.004676           -0.007010
# AirlineID            -0.009645 -0.008096            0.025930
# Quarter              -0.007060 -0.006550            0.002641
# FlightNum             0.006254  0.008467            0.009315
# OriginAirportID      -0.004198 -0.002500            0.001261
# CRSElapsedTime        0.014779  0.012388           -0.011407
# DepTime               0.647303  0.618038            0.175366
# DepDelayMinutes       0.029159  0.020741            0.819736
# DepartureDelayGroups  0.066147  0.054945            0.916818
# WheelsOff             0.669376  0.639933            0.170498
# TaxiOut               0.039235  0.035979            0.262730
# TaxiIn                0.003360  0.005950            0.128127
# WheelsOn              1.000000  0.965927            0.061040
# ArrTime               0.965927  1.000000            0.049988
# ArrivalDelayGroups    0.061040  0.049988            1.000000
# ActualElapsedTime     0.017795  0.014940            0.052682
# ArrDelayMinutes       0.028060  0.019445            0.853607
#
#                       ActualElapsedTime  ArrDelayMinutes
# Year                           0.011668         0.023551
# CRSDepTime                    -0.015018         0.093004
# CRSArrTime                     0.025337         0.081736
# DestAirportID                  0.092996         0.004308
# Distance                       0.973637         0.007168
# Month                         -0.004356        -0.001643
# DayofMonth                    -0.000801        -0.008875
# DayOfWeek                      0.013515        -0.002899
# AirlineID                      0.037778         0.046754
# Quarter                       -0.004342         0.000025
# FlightNum                     -0.287826         0.012248
# OriginAirportID                0.055521        -0.001689
# CRSElapsedTime                 0.985297         0.012133
# DepTime                       -0.019914         0.127348
# DepDelayMinutes                0.021848         0.973221
# DepartureDelayGroups           0.037795         0.837638
# WheelsOff                     -0.025611         0.121107
# TaxiOut                        0.208406         0.183695
# TaxiIn                         0.194771         0.089304
# WheelsOn                       0.017795         0.028060
# ArrTime                        0.014940         0.019445
# ArrivalDelayGroups             0.052682         0.853607
# ActualElapsedTime              1.000000         0.046880
# ArrDelayMinutes                0.046880         1.000000
#
# [24 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# from pylab import *
# t = arange(0.0, 2.0, 0.01)
# s = sin(2.5*pi*t)
# plot(t, s)
 
# xlabel('time (s)')
# ylabel('voltage (mV)')
# title('Sine Wave')
# grid(True)
# show()

# %%
# import pandas
# import numpy
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import chi2
# # load data
# array = df.values
# X = array[:,0:8]
# Y = array[:,8]
# # feature extraction
# test = SelectKBest(score_func=chi2, k=4)
# fit = test.fit(X, Y)
# # summarize scores
# numpy.set_printoptions(precision=3)
# print(fit.scores_)
# features = fit.transform(X)
# # summarize selected features
# print(features[0:5,:])

# %%
df.columns
# Out:
# Index(['FlightNum', 'Year', 'Day', 'Month', 'Week', 'Origin', 'Dest',
#        'UniqueCarrier', 'ArrTime', 'DepTime', 'CRSArrTime', 'CRSDepTime',
#        'CRSElapsedTime', 'ActualElapsedTime', 'ArrDelayMinutes',
#        'DepDelayMinutes', 'OriginCityName', 'DestCityName', 'Flight_Status',
#        'OriginVisibility', 'OriginWind', 'OriginPrecip'],
#       dtype='object')

# %%
cols = df.columns.tolist()
cols.remove('DepDelayMinutes')
cols.remove('OriginWind')
cols.remove('OriginVisibility')
cols.remove('Flight_Status')

# %%
X = df[cols]
y=df['DepDelayMinutes']

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
# Converting the categorical data to numeric 

X['carrier'] = label_encoder.fit_transform(X['UniqueCarrier'])
X['origin'] = label_encoder.fit_transform(X['Origin'])
X['dest'] = label_encoder.fit_transform(X['Dest'])
X['ori_city'] = label_encoder.fit_transform(X['OriginCityName'])
X['dest_city'] = label_encoder.fit_transform(X['DestCityName'])

X = X._get_numeric_data()

# %%
len(X.columns)
# Out:
# 18

# %%
X.columns
# Out:
# Index(['FlightNum', 'Year', 'Day', 'Month', 'Week', 'ArrTime', 'DepTime',
#        'CRSArrTime', 'CRSDepTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'ArrDelayMinutes', 'OriginPrecip', 'carrier', 'origin', 'dest',
#        'ori_city', 'dest_city'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier

# Build a classification task using 3 informative features
X, y = make_classification(n_samples=1000,
                           n_features=18,
                           n_informative=3,
                           n_redundant=0,
                           n_repeated=0,
                           n_classes=2,
                           random_state=0,
                           shuffle=False)

# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)

forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
    
# Plot the feature importances of the forest

plt.figure(figsize=(18, 6))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 1 (0.249117)
# 2. feature 2 (0.150414)
# 3. feature 0 (0.119173)
# 4. feature 6 (0.033781)
# 5. feature 11 (0.033348)
# 6. feature 8 (0.033210)
# 7. feature 12 (0.032777)
# 8. feature 10 (0.032680)
# 9. feature 13 (0.032615)
# 10. feature 15 (0.032508)
# 11. feature 7 (0.032418)
# 12. feature 17 (0.032372)
# 13. feature 16 (0.032064)
# 14. feature 5 (0.031897)
# 15. feature 3 (0.030820)
# 16. feature 4 (0.030617)
# 17. feature 9 (0.030210)
# 18. feature 14 (0.029979)

# %% [markdown]
# ####

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
# Converting the categorical data to numeric 
X['carrier'] = label_encoder.fit_transform(X['UniqueCarrier'])
X['status'] = label_encoder.fit_transform(X['Status'])
X['origin'] = label_encoder.fit_transform(X['Origin'])
X['dest'] = label_encoder.fit_transform(X['Dest'])
X['ori_city'] = label_encoder.fit_transform(X['OriginCityName'])
X['ori_state'] = label_encoder.fit_transform(X['OriginStateName'])
X['dest_city'] = label_encoder.fit_transform(X['DestCityName'])
X['dest_state'] = label_encoder.fit_transform(X['DestStateName'])

# %%
y = np.ravel(y)
X = X._get_numeric_data()

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier

# Build a classification task using 3 informative features
X, y = make_classification(n_samples=1000,
                           n_features=30,
                           n_informative=3,
                           n_redundant=0,
                           n_repeated=0,
                           n_classes=2,
                           random_state=0,
                           shuffle=False)

# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)

forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 1 (0.195727)
# 2. feature 2 (0.092816)
# 3. feature 0 (0.077242)
# 4. feature 10 (0.025414)
# 5. feature 8 (0.025293)
# 6. feature 7 (0.024502)
# 7. feature 12 (0.024410)
# 8. feature 3 (0.024357)
# 9. feature 15 (0.024315)
# 10. feature 25 (0.023910)
# 11. feature 22 (0.023864)
# 12. feature 13 (0.023825)
# 13. feature 11 (0.023708)
# 14. feature 21 (0.023621)
# 15. feature 24 (0.023592)
# 16. feature 29 (0.023547)
# 17. feature 14 (0.023540)
# 18. feature 5 (0.023244)
# 19. feature 17 (0.023176)
# 20. feature 16 (0.023143)
# 21. feature 28 (0.023138)
# 22. feature 9 (0.023126)
# 23. feature 23 (0.022898)
# 24. feature 26 (0.022881)
# 25. feature 18 (0.022772)
# 26. feature 4 (0.022760)
# 27. feature 27 (0.022595)
# 28. feature 6 (0.022584)
# 29. feature 19 (0.022105)
# 30. feature 20 (0.021894)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a03babc5c002> in <module>()
#       4 plt.figure()
#       5 plt.title("Feature importances")
# ----> 6 plt.bar(range(X.shape[1]), importances[indices],
#       7        color="r", yerr=std[indices], align="center")
#       8 plt.xticks(range(X.shape[1]), indices)
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## PCA

# %%
import numpy
from pandas import read_csv
from sklearn.decomposition import PCA
# load data
array = df.values
X = array[:,0:8]
y = array[:,8]
# feature extraction
pca = PCA(n_components=8)
fit = pca.fit(X)
# summarize components
print("Explained Variance: %s",fit.explained_variance_ratio_)
print(fit.components_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-46abacfc88ec> in <module>()
#       8 # feature extraction
#       9 pca = PCA(n_components=8)
# ---> 10 fit = pca.fit(X)
#      11 # summarize components
#      12 print("Explained Variance: %s",fit.explained_variance_ratio_)
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/site-packages/sklearn/decomposition/pca.py in fit(self, X, y)
#     327             Returns the instance itself.
#     328         """
# --> 329         self._fit(X)
#     330         return self
#     331
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     368
#     369         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 370                         copy=self.copy)
#     371
#     372         # Handle n_components==None
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Massachusetts'

# %% [markdown]
# ## RFE

# %%
# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data
array = df.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
model = LogisticRegression()
rfe = RFE(model, 3)
fit = rfe.fit(X, Y)
print("Num Features: %d") % fit.n_features_
print("Selected Features: %s") % fit.support_
print("Feature Ranking: %s") % fit.ranking_

# %% [markdown]
# df.head()

# %%
import sklearn
from sklearn import *

# %%
# Create linear regression object
lm = linear_model.LinearRegression()

# %%
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_
# Out:
# array([  6.15155963e-14,   1.73743398e-17,  -2.49366500e-18,
#          9.75781955e-19,   2.38524478e-18,   8.97502558e-16,
#          2.10335221e-17,   1.54607230e-16,   2.38524478e-18,
#         -3.22701935e-15,   4.33680869e-19,  -1.51788304e-18,
#          6.25584654e-17,  -2.60208521e-18,   2.36356074e-17,
#          2.29693651e-15,   8.67361738e-19,  -3.90312782e-18,
#         -8.08001669e-17,  -1.08420217e-19,   5.42101086e-19,
#         -1.53563685e-16,  -7.45931095e-17,  -3.12250226e-17,
#          4.31376939e-17,  -1.00000000e+00,   3.07777892e-17,
#         -1.66018458e-17,   1.73472348e-18,  -4.63496429e-18,
#         -1.30104261e-18,   1.72659196e-17])

# %%
lm.intercept_
# Out:
# 0.99999999987589672
