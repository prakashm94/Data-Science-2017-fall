# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # Reading and concatinating the Flight Delay Data

# %%
cur_path = '/Users/sonalichaudhari/Desktop/ADS_Project/Data'

# %%
#Read in the flight delay and concatinate it
d1 = pd.read_csv(open(cur_path+'/Data2016_Cleaned.csv', 'rU'), encoding = 'utf-8')
d2 = pd.read_csv(open(cur_path+'/Data2017_Cleaned.csv', 'rU'), encoding = 'utf-8')

df = pd.concat([d1,d2])

# %% [markdown]
# # Data for  Airports

# %%
# airports taken into consideration
airport = ['DFW', 'DTW', 'SEA', 'JFK', 'SJC', 'ORD', 'PHX', 'STL', 'LAX',
       'MCO', 'DEN', 'MIA', 'IAH','SLC', 'TUS','BOS', 'FLL', 'SFO', 'OGG', 'TPA', 'SNA', 'OKC', 'HNL',
       'PHL', 'LGA', 'RDU', 'DCA', 'RIC', 'ATL', 'LBB', 'CLT', 'ELP',
       'BNA', 'JAC', 'SMF', 'EWR', 'IAD', 'LIH', 'SJU', 'ABQ',
       'ORF', 'JAX', 'MSY','MCI', 'GUC', 'IND', 'PDX', 'BWI',
       'MSP', 'MKE', 'ONT', 'RSW', 'DSM', 'PSP',
       'EGE', 'PBI', 'SDF', 'PIT', 'DAY', 'STX', 'COS',
       'CMH', 'MTJ', 'HDN', 'BDL', 'MEM', 'CLE', 'HOU','OAK',
       'GEG', 'ANC', 'BUF', 'SYR', 'ALB', 'PVD','ILM', 'ICT',
       'PWM', 'GSO', 'CHS', 'MDT', 'BHM', 'ADQ', 'BRW', 'SCC',
       'JNU', 'KTN', 'YAK', 'CDV','PSG', 'WRG', 'OME',
       'OTZ', 'BUR', 'ADK', 'SWF', 'LGB', 'PSE', 'BQN', 'HPN',
       'SAV', 'SRQ', 'BTV', 'ORH','CVG', 'BIS', 'AVL', 'GRR',
       'FNT', 'MYR', 'JAN', 'FAR', 'PNS', 'AGS','LEX',
       'DAL', 'ATW', 'GPT', 'MLB', 'BZN', 'CHO', 'MSN', 'EYW',
       'TRI', 'LFT', 'ROA', 'ECP', 'VPS', 'XNA', 'EVV', 'AVP', 'MDW',
       'HSV', 'FAY', 'TYS', 'TLH', 'MSO','TTN',
       'PHF', 'FSD', 'LBE','BMI', 'CRW','PPG', 'IAG', 'ACT','SHV', 'FSM', 'MAF',
       'SAF', 'JLN', 'LRD', 'BRO', 'TYR', 'GJT', 'DLH',
       'SBA', 'ASE', 'IDA', 'RAP', 'FCA', 'LNK', 'AMA',
       'BFL', 'MLI', 'LSE', 'SBN', 'PSC','FLG', 'ISN', 'GFK',
       'GTF', 'MRY', 'MBS', 'SUN', 'TWF', 'SGF', 'CPR',
       'BTR', 'PBG', 'CRP', 'CID', 'SBP', 'RKS', 'CMX', 'MMH', 'PLN',
       'EKO', 'GCC', 'MFR', 'SMX', 'EUG', 'RST', 'TVC', 'SPI',
       'SGU', 'HLN', 'RDM', 'ACV', 'EAU', 'DVL', 'JMS', 'MKG', 'HYS',
       'COD', 'ITH', 'APN', 'ESC', 'BJI', 'MQT',
       'BGM', 'RHI', 'LWS', 'IMT', 'BRD', 'INL', 'PIH', 'GUM', 'HIB',
       'BTM', 'CDC', 'OTH', 'RDD', 'HRL', 'ISP', 'MHT', 'GNV',
       'MEI', 'PIB', 'BPT',  'AEX', 'TXK', 'ROW', 'CLL',
       'HOB', 'LCH', 'OAJ', 'ELM', 'VLD', 'MGM', 'BGR', 'GTR',
       'CSG', 'BQK', 'DHN', 'EWN', 'ABY', 'SPS', 'SJT', 'GGG',
       'ACK', 'MVY', 'HYA', 'GST', 'AKN', 'DLG', 'GCK', 'MHK',
       'ABI', 'GRI', 'EFD', 'PGD', 'SPN']

# %%
#Fintering out data from flight delay to just have the top 10 airport airports
dt_both = df[df.Origin.isin(airport)]

# %%
dt_both = dt_both[dt_both.Dest.isin(airport)]

# %%
len(dt_both)

# %% [markdown]
# # Reading in the Weather Data

# %%
df_weather = pd.read_csv(cur_path+'/WeatherData.csv', low_memory=False)
#df_weather2017 = pd.read_csv(cur_path+'/weatherdata/weatherdata2017.csv', low_memory=False)
#df_weather = pd.concat([df_weather2016,df_weather2017])

# %%
df_weather_origin = df_weather[['station', 'Year', 'Month', 'DayofMonth', 'Visibility', 'Wind', 'Precip']]
df_weather_dest = df_weather[['station', 'Year', 'Month', 'DayofMonth', 'Visibility', 'Wind', 'Precip']]

# %%
df_weather_origin.columns = ['Origin', 'Year', 'Month', 'DayofMonth', 'OriginVisibility', 'OriginWind', 'OriginPrecip']
df_weather_dest.columns = ['Dest', 'Year', 'Month', 'DayofMonth', 'DestinationVisibility', 'DestinationWind', 'DestinationPrecip']

# %% [markdown]
# # Merging Weather and Flight delay

# %%
result = dt_both.merge(df_weather_origin.drop_duplicates(subset=['Origin', 'Year','Month', 'DayofMonth']), how='left',on=['Origin', 'Year','Month', 'DayofMonth'])

# %%
final_combined = result.merge(df_weather_dest.drop_duplicates(subset=['Dest', 'Year','Month', 'DayofMonth']), on=['Dest', 'Year','Month', 'DayofMonth'], how='left')

# %%
len(final_combined)
# Out:
# 8058380

# %% [markdown]
# # Dealing with Missing Data

# %%
final_combined.isnull().sum()
# Out:
# ActualElapsedTime              0
# AirlineID                      0
# ArrDelayMinutes                0
# ArrTime                        0
# ArrivalDelayGroups             0
# CRSArrTime                     0
# CRSDepTime                     0
# CRSElapsedTime                 0
# DayOfWeek                      0
# DayofMonth                     0
# DepDelayMinutes                0
# DepTime                        0
# DepartureDelayGroups           0
# Dest                           0
# DestAirportID                  0
# DestCityMarketID               0
# DestCityName                   0
# DestState                      0
# DestStateName                  0
# Distance                       0
# DivAirportLandings             1
# FlightNum                      0
# Month                          0
# Origin                         0
# OriginAirportID                0
# OriginCityName                 0
# OriginStateName                0
# Quarter                        0
# TaxiIn                         0
# TaxiOut                        0
# UniqueCarrier                  0
# WheelsOff                      0
# WheelsOn                       0
# Year                           0
# OriginVisibility         2882914
# OriginWind               2882914
# OriginPrecip             2882914
# DestinationVisibility    2883781
# DestinationWind          2883781
# DestinationPrecip        2883781
# dtype: int64

# %%
final_combined.OriginVisibility = final_combined.OriginVisibility.fillna((final_combined.OriginVisibility.fillna(method='ffill') +final_combined.OriginVisibility.fillna(method='bfill'))/2)
final_combined.DestinationVisibility = final_combined.DestinationVisibility.fillna((final_combined.DestinationVisibility.fillna(method='ffill') +final_combined.DestinationVisibility.fillna(method='bfill'))/2)
final_combined.OriginWind = final_combined.OriginWind.fillna((final_combined.OriginWind.fillna(method='ffill') +final_combined.OriginWind.fillna(method='bfill'))/2)
final_combined.DestinationWind = final_combined.DestinationWind.fillna((final_combined.DestinationWind.fillna(method='ffill') +final_combined.DestinationWind.fillna(method='bfill'))/2)
final_combined.OriginPrecip = final_combined.OriginPrecip.fillna((final_combined.OriginPrecip.fillna(method='ffill') +final_combined.OriginPrecip.fillna(method='bfill'))/2)
final_combined.DestinationPrecip = final_combined.DestinationPrecip.fillna((final_combined.DestinationPrecip.fillna(method='ffill') +final_combined.DestinationPrecip.fillna(method='bfill'))/2)

# %%
df_dec = final_combined.loc[(final_combined['Month']==9)]

# %%
mode_vis = df_dec.OriginVisibility.mode()[0]
mode_wind = df_dec.OriginWind.mode()[0]
mode_pre = df_dec.OriginPrecip.mode()[0]

# %%
final_combined.OriginVisibility = final_combined.OriginVisibility.fillna(mode_vis)
final_combined.OriginWind = final_combined.OriginWind.fillna(mode_wind)
final_combined.OriginPrecip = final_combined.OriginPrecip.fillna(mode_pre)

# %%
final_combined.to_csv(cur_path+'/Airports.csv')

# %% [markdown]
# # Analysis on null values and how to deal with them

# %%
#Seeing how many null values exist after merging in weather data
final_combined.isnull().sum()
# Out:
# ActualElapsedTime        0
# AirlineID                0
# ArrDelayMinutes          0
# ArrTime                  0
# ArrivalDelayGroups       0
# CRSArrTime               0
# CRSDepTime               0
# CRSElapsedTime           0
# DayOfWeek                0
# DayofMonth               0
# DepDelayMinutes          0
# DepTime                  0
# DepartureDelayGroups     0
# Dest                     0
# DestAirportID            0
# DestCityMarketID         0
# DestCityName             0
# DestState                0
# DestStateName            0
# Distance                 0
# DivAirportLandings       1
# FlightNum                0
# Month                    0
# Origin                   0
# OriginAirportID          0
# OriginCityName           0
# OriginStateName          0
# Quarter                  0
# TaxiIn                   0
# TaxiOut                  0
# UniqueCarrier            0
# WheelsOff                0
# WheelsOn                 0
# Year                     0
# OriginVisibility         3
# OriginWind               3
# OriginPrecip             3
# DestinationVisibility    0
# DestinationWind          0
# DestinationPrecip        0
# dtype: int64

# %%
final_combined[final_combined.OriginVisibility.isnull()]
# Out:
#          ActualElapsedTime  AirlineID  ArrDelayMinutes  ArrTime  \
# 9151048               69.0      20409              0.0    732.0
# 9151049               68.0      20409              0.0    802.0
# 9151050              175.0      20409              0.0   1247.0
#
#          ArrivalDelayGroups  CRSArrTime  CRSDepTime  CRSElapsedTime  \
# 9151048                -1.0         743         630            73.0
# 9151049                -1.0         812         700            72.0
# 9151050                -1.0        1301        1001           180.0
#
#          DayOfWeek  DayofMonth        ...          UniqueCarrier  WheelsOff  \
# 9151048          1          25        ...                     B6      636.0
# 9151049          1          25        ...                     B6      705.0
# 9151050          1          25        ...                     B6     1003.0
#
#          WheelsOn  Year  OriginVisibility  OriginWind OriginPrecip  \
# 9151048     728.0  2017               NaN         NaN          NaN
# 9151049     757.0  2017               NaN         NaN          NaN
# 9151050    1242.0  2017               NaN         NaN          NaN
#
#         DestinationVisibility DestinationWind  DestinationPrecip
# 9151048                   7.0             5.0               0.04
# 9151049                   7.0             5.0               0.04
# 9151050                   7.0             5.0               0.04
#
# [3 rows x 40 columns]

# %%
final_combined.OriginVisibility.unique()
# Out:
# array([ 11. ,   5. ,   8. ,   7. ,   6. ,   4. ,  12. ,   9. ,  10. ,
#          3. ,  16. ,  19. ,  17. ,  18. ,  15. ,  14. ,   1. ,  13. ,
#         17.5,   2. ,   8.5,   9.5,  18.5,  13.5,  16.5,   6.5,  10.5,
#          7.5,  11.5,  12.5,  14.5,  15.5,   5.5])

# %%
temp =final_combined[['Year','Month','DayofMonth', 'Origin', 'Dest','OriginVisibility', 'OriginWind', 'OriginPrecip', 'DestinationVisibility', 'DestinationWind', 'DestinationPrecip']]

# %%
temp[temp.OriginVisibility.isnull()]
# Out:
#          Year  Month  DayofMonth Origin Dest  OriginVisibility  OriginWind  \
# 9151048  2017      9          25    JAX  FLL               NaN         NaN
# 9151049  2017      9          25    FLL  JAX               NaN         NaN
# 9151050  2017      9          25    PBI  BOS               NaN         NaN
#
#          OriginPrecip  DestinationVisibility  DestinationWind  \
# 9151048           NaN                    7.0              5.0
# 9151049           NaN                    7.0              5.0
# 9151050           NaN                    7.0              5.0
#
#          DestinationPrecip
# 9151048               0.04
# 9151049               0.04
# 9151050               0.04

# %%
den = temp.loc[(temp['Origin']=='DEN')]

# %%
#Tried for each month and summed the missing values
feb = den.loc[(den['Month']==3)]

# %%
feb
# Out:
#         Year  Month  DayofMonth Origin Dest  OriginVisibility  OriginWind  \
# 48476   2016      3           1    DEN  DFW              19.0         7.0
# 48477   2016      3           2    DEN  DFW              18.0         4.0
# 48478   2016      3           3    DEN  DFW              19.0         0.0
# 48479   2016      3           4    DEN  DFW              17.0         3.0
# 48480   2016      3           5    DEN  DFW              18.0         2.0
# 48481   2016      3           6    DEN  DFW              18.0         2.0
# 48482   2016      3           7    DEN  DFW              18.0         2.0
# 48483   2016      3           8    DEN  DFW              16.0         0.0
# 48484   2016      3           9    DEN  DFW              19.0         3.0
# 48485   2016      3          10    DEN  DFW              19.0         6.0
# 48486   2016      3          11    DEN  DFW              18.0         9.0
# 48487   2016      3          12    DEN  DFW              19.0        11.0
# 48488   2016      3          13    DEN  DFW              16.0         7.0
# 48489   2016      3          14    DEN  DFW              19.0         5.0
# 48490   2016      3          15    DEN  DFW              19.0         3.0
# 48491   2016      3          16    DEN  DFW              18.0         8.0
# 48492   2016      3          17    DEN  DFW              18.0         2.0
# 48493   2016      3          18    DEN  DFW              17.0         2.5
# 48494   2016      3          19    DEN  DFW              16.0         3.0
# 48495   2016      3          20    DEN  DFW              18.0         8.0
# 48496   2016      3          21    DEN  DFW              18.0         4.0
# 48497   2016      3          22    DEN  DFW              18.0         3.0
# 48498   2016      3          23    DEN  DFW              17.0         2.0
# 48499   2016      3          24    DEN  DFW              18.0         6.0
# 48503            0.0                   10.0              6.0
# 48504            0.0                   10.0             13.0
# 48505            0.0                    8.0             17.0
# ...              ...                    ...              ...
# 403910           0.0                   10.0              5.0
# 403911           0.0                   10.0              5.0
# 403912           0.0                   10.0              5.0
# 403913           0.0                   10.0              5.0
# 403927           0.0                    8.0              6.0
# 403928           0.0                    8.0              6.0
# 403929           0.0                    4.0              8.0
# 403930           0.0                    4.0              8.0
# 403931           0.0                    4.0              8.0
# 403932           0.0                    3.0             11.0
# 403933           0.0                    3.0             11.0
# 403934           0.0                    5.0              7.0
# 403935           0.0                    5.0              7.0
# 403936           0.0                   10.0             14.0
# 403937           0.0                   10.0             14.0
# 403938           0.0                   10.0             14.0
# 403939           0.0                   10.0             14.0
# 403953           0.0                    9.0              6.0
# 403954           0.0                    9.0              6.0
# 403955           0.0                   10.0             15.0
# 403956           0.0                   10.0             15.0
# 403957           0.0                   10.0             15.0
# 403958           0.0                   10.0             13.0
# 403959           0.0                   10.0             13.0
# 403960           0.0                   10.0             13.0
# 403961           0.0                   10.0             13.0
# 403962           0.0                   10.0             15.0
# 403963           0.0                   10.0             15.0
# 403964           0.0                   10.0             15.0
# 403965           0.0                   10.0             15.0
#
#         DestinationPrecip
# 48476                0.00
# 48477                0.00
# 48478                0.00
# 48479                0.00
# 48480                0.00
# 48481                0.00
# 48482                0.04
# 48483                0.97
# 48484                0.57
# 48485                0.33
# 48486                0.08
# 48487                0.10
# 48488                0.00
# 48489                0.00
# 48490                0.00
# 48491                0.00
# 48492                0.00
# 48493                0.00
# 48494                0.00
# 48495                0.00
# 48496                0.00
# 48497                0.00
# 48498                0.42
# 48499                0.00
# 48500                0.00
# 48501                0.00
# 48502                0.00
# 48503                0.00
# 48504                0.00
# 48505                0.16
# ...                   ...
# 403910               0.00
# 403911               0.00
# 403912               0.00
# 403913               0.00
# 403927               0.00
# 403928               0.00
# 403929               0.99
# 403930               0.99
# 403931               0.99
# 403932               0.65
# 403933               0.65
# 403934               0.45
# 403935               0.45
# 403936               0.00
# 403937               0.00
# 403938               0.00
# 403939               0.00
# 403953               0.00
# 403954               0.00
# 403955               0.00
# 403956               0.00
# 403957               0.00
# 403958               0.00
# 403959               0.00
# 403960               0.00
# 403961               0.00
# 403962               0.00
# 403963               0.00
# 403964               0.00
# 403965               0.00
#
# [6350 rows x 11 columns]

# %%
feb[feb.OriginVisibility.isnull()]
# Out:
#         Year  Month  DayofMonth Origin Dest  OriginVisibility  OriginWind  \
# 48493   2016      3          18    DEN  DFW               NaN         NaN
# 49841   2016      3          18    DEN  DFW               NaN         NaN
# 49927   2016      3          18    DEN  DFW               NaN         NaN
# 51101   2016      3          18    DEN  DFW               NaN         NaN
# 51889   2016      3          18    DEN  DFW               NaN         NaN
# 52141   2016      3          18    DEN  ORD               NaN         NaN
# 52644   2016      3          18    DEN  DFW               NaN         NaN
# 52703   2016      3          18    DEN  DFW               NaN         NaN
# 53554   2016      3          18    DEN  DFW               NaN         NaN
# 53786   2016      3          18    DEN  ORD               NaN         NaN
# 54054   2016      3          18    DEN  DFW               NaN         NaN
# 54399   2016      3          18    DEN  ORD               NaN         NaN
# 55568   2016      3          18    DEN  PHL               NaN         NaN
# 55664   2016      3          18    DEN  PHL               NaN         NaN
# 56857   2016      3          18    DEN  DFW               NaN         NaN
# 58271   2016      3          18    DEN  JFK               NaN         NaN
# 58413   2016      3          18    DEN  BOS               NaN         NaN
# 58436   2016      3          18    DEN  BOS               NaN         NaN
# 59983   2016      3          18    DEN  LGA               NaN         NaN
# 59984   2016      3          18    DEN  JFK               NaN         NaN
# 59998   2016      3          18    DEN  LGA               NaN         NaN
# 59999   2016      3          18    DEN  LGA               NaN         NaN
# 60547   2016      3          18    DEN  JFK               NaN         NaN
# 60878   2016      3          18    DEN  PHL               NaN         NaN
# 60879   2016      3          18    DEN  SFO               NaN         NaN
# 62365   2016      3          18    DEN  BOS               NaN         NaN
# 62366   2016      3          18    DEN  BOS               NaN         NaN
# 62367   2016      3          18    DEN  EWR               NaN         NaN
# 62368   2016      3          18    DEN  EWR               NaN         NaN
# 62396   2016      3          18    DEN  LGA               NaN         NaN
# ...      ...    ...         ...    ...  ...               ...         ...
# 403647  2017      3           9    DEN  LGA               NaN         NaN
# 403648  2017      3           9    DEN  PHL               NaN         NaN
# 403649  2017      3           9    DEN  PHL               NaN         NaN
# 403650  2017      3           9    DEN  SFO               NaN         NaN
# 403651  2017      3           9    DEN  SFO               NaN         NaN
# 403652  2017      3           9    DEN  SFO               NaN         NaN
# 403653  2017      3           9    DEN  SFO               NaN         NaN
# 403863  2017      3           5    DEN  BOS               NaN         NaN
# 403864  2017      3           5    DEN  EWR               NaN         NaN
# 403865  2017      3           5    DEN  EWR               NaN         NaN
# 403866  2017      3           5    DEN  LGA               NaN         NaN
# 403867  2017      3           5    DEN  LGA               NaN         NaN
# 403868  2017      3           5    DEN  PHL               NaN         NaN
# 403869  2017      3           5    DEN  PHL               NaN         NaN
# 403870  2017      3           5    DEN  SFO               NaN         NaN
# 403871  2017      3           5    DEN  SFO               NaN         NaN
# 403872  2017      3           5    DEN  SFO               NaN         NaN
# 403880  2017      3          12    DEN  BOS               NaN         NaN
# 403881  2017      3          12    DEN  BOS               NaN         NaN
# 403882  2017      3          12    DEN  EWR               NaN         NaN
# 403883  2017      3          12    DEN  EWR               NaN         NaN
# 403884  2017      3          12    DEN  EWR               NaN         NaN
# 403885  2017      3          12    DEN  LGA               NaN         NaN
# 403886  2017      3          12    DEN  LGA               NaN         NaN
# 403887  2017      3          12    DEN  LGA               NaN         NaN
# 403888  2017      3          12    DEN  PHL               NaN         NaN
# 403889  2017      3          12    DEN  PHL               NaN         NaN
# 403890  2017      3          12    DEN  SFO               NaN         NaN
# 403891  2017      3          12    DEN  SFO               NaN         NaN
# 403892  2017      3          12    DEN  SFO               NaN         NaN
#
#         OriginPrecip  DestinationVisibility  DestinationWind  \
# 48493            NaN                    9.0             12.0
# 49841            NaN                    9.0             12.0
# 49927            NaN                    9.0             12.0
# 51101            NaN                    9.0             12.0
# 51889            NaN                    9.0             12.0
# 52141            NaN                   10.0             13.0
# 52644            NaN                    9.0             12.0
