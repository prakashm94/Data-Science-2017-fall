# %% [markdown]
# # DATA CLEANING 2016

# %% [markdown]
# ### Imports

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ### Loading the Csvs and combining into a single dataframe

# %%
cur_path = '/Users/sonalichaudhari/Desktop/ADS_Project/Data'
df = pd.read_csv(open(cur_path+'/Data2016_Uncleaned.csv','rU'), encoding='utf-8')
df.shape
# Out:
# (5617658, 109)

# %% [markdown]
# ### CLEANING

# %% [markdown]
# ### Getting rid of columns having 98% or more missing data

# %%
missing_data = df.isnull().sum().to_frame(name='Missing_Count').reset_index()
missing_data['Missing_percent'] = (missing_data['Missing_Count']/df.shape[0])*100
missing_data = missing_data.sort_values(by='Missing_percent', axis=0, ascending=True)
features = missing_data['index'][(missing_data.Missing_percent<99.38)]
len(features)
# Out:
# 62

# %%
# Considering only the columns having more than 99.38% of data
d = df[features]

# Renaming the columns
d = d.rename(columns = {'DayofMonth':'Day','DayOfWeek':'Week'})

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()
plt.figure(figsize = (30,20))
sns.set(font_scale = 2)
sns.heatmap(data=dd.corr())
plt.show()
plt.gcf().clear()

# %%
dd = df [['TailNum',
 'DepTime',
 'DepDelay',
 'DepDelayMinutes',
 'DepDel15',
 'DepartureDelayGroups',
 'WheelsOff',
 'TaxiOut',
 'TaxiIn',
 'WheelsOn',
 'ArrTime',
 'ArrivalDelayGroups',
 'ActualElapsedTime',
 'AirTime',
 'ArrDel15',
 'ArrDelayMinutes',
 'ArrDelay',
 'SecurityDelay',
 'LateAircraftDelay',
 'WeatherDelay',
 'CarrierDelay',
 'NASDelay',
 'CancellationCode']]

# %%
d.columns.tolist()
# Out:
# ['Year',
#  'DestCityMarketID',
#  'Dest',
#  'DestCityName',
#  'DestState',
#  'DestStateFips',
#  'DestStateName',
#  'DestWac',
#  'DestAirportSeqID',
#  'CRSDepTime',
#  'CRSArrTime',
#  'ArrTimeBlk',
#  'Cancelled',
#  'Diverted',
#  'Flights',
#  'DistanceGroup',
#  'DivAirportLandings',
#  'DepTimeBlk',
#  'DestAirportID',
#  'Distance',
#  'OriginStateName',
#  'OriginWac',
#  'Month',
#  'Day',
#  'Week',
#  'FlightDate',
#  'UniqueCarrier',
#  'AirlineID',
#  'Carrier',
#  'Quarter',
#  'Origin',
#  'OriginStateFips',
#  'OriginState',
#  'OriginCityName',
#  'FlightNum',
#  'OriginCityMarketID',
#  'OriginAirportSeqID',
#  'OriginAirportID',
#  'CRSElapsedTime',
#  'TailNum',
#  'DepTime',
#  'DepDelay',
#  'DepDelayMinutes',
#  'DepDel15',
#  'DepartureDelayGroups',
#  'WheelsOff',
#  'TaxiOut',
#  'TaxiIn',
#  'WheelsOn',
#  'ArrTime',
#  'ArrivalDelayGroups',
#  'ActualElapsedTime',
#  'AirTime',
#  'ArrDel15',
#  'ArrDelayMinutes',
#  'ArrDelay',
#  'SecurityDelay',
#  'LateAircraftDelay',
#  'WeatherDelay',
#  'CarrierDelay',
#  'NASDelay',
#  'CancellationCode']

# %%
d.isnull().sum().sort_values()
# Out:
# Year                          0
# OriginWac                     0
# Month                         0
# Day                           0
# Week                          0
# FlightDate                    0
# UniqueCarrier                 0
# AirlineID                     0
# OriginStateName               0
# Carrier                       0
# OriginStateFips               0
# OriginState                   0
# OriginCityName                0
# FlightNum                     0
# OriginCityMarketID            0
# OriginAirportSeqID            0
# OriginAirportID               0
# Quarter                       0
# Distance                      0
# Origin                        0
# DepTimeBlk                    0
# DestCityMarketID              0
# Dest                          0
# DestCityName                  0
# DestState                     0
# DestStateFips                 0
# DestStateName                 0
# DestWac                       0
# DestAirportID                 0
# DestAirportSeqID              0
#                          ...
# ArrTimeBlk                    0
# Cancelled                     0
# Diverted                      0
# Flights                       0
# DistanceGroup                 0
# DivAirportLandings            0
# CRSElapsedTime                6
# TailNum                   12892
# DepartureDelayGroups      63456
# DepDel15                  63456
# DepTime                   63456
# DepDelay                  63456
# DepDelayMinutes           63456
# WheelsOff                 65418
# TaxiOut                   65418
# TaxiIn                    67844
# WheelsOn                  67844
# ArrTime                   67844
# ArrDelay                  79513
# ArrDelayMinutes           79513
# ArrDel15                  79513
# AirTime                   79513
# ArrivalDelayGroups        79513
# ActualElapsedTime         79513
# NASDelay                4653419
# SecurityDelay           4653419
# LateAircraftDelay       4653419
# WeatherDelay            4653419
# CarrierDelay            4653419
# CancellationCode        5551797
# dtype: int64

# %%
type(d.ArrTimeBlk)
# Out:
# pandas.core.series.Series

# %%
d.ArrTimeBlk.unique()
# Out:
# array(['1400-1459', '1700-1759', '1600-1659', '1500-1559', '2100-2159',
#        '2000-2059', '1800-1859', '1900-1959', '2200-2259', '2300-2359',
#        '1200-1259', '1300-1359', '0001-0559', '1100-1159', '1000-1059',
#        '0700-0759', '0600-0659', '0900-0959', '0800-0859'], dtype=object)

# %%
d[['DepTime','FirstDepTime']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-db9266ed0de5> in <module>()
# ----> 1 d[['DepTime','FirstDepTime']]
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
# -> 2097             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2098             return self.take(indexer, axis=1, convert=True)
#    2099
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1228                 mask = check == -1
#    1229                 if mask.any():
# -> 1230                     raise KeyError('%s not in index' % objarr[mask])
#    1231
#    1232                 return _values_from_object(indexer)
#
# KeyError: "['FirstDepTime'] not in index"

# %%
d.shape
# Out:
# (5617658, 62)

# %%
cancel_dict
# Out:
# {'A': ['Carrier'],
#  'B': ['Weather'],
#  'C': ['National Air System'],
#  'D': ['Security']}

# %%
d.CancellationCode.unique()
# Out:
# array([nan, 'A', 'B', 'C', 'D'], dtype=object)

# %%
d.CancellationCode.value_counts()
# Out:
# B    34465
# A    20279
# C    11091
# D       26
# Name: CancellationCode, dtype: int64

# %%
# d= d[d.Cancelled==0]
# d.shape
# Out:
# (5551797, 62)

# %%
d.WeatherDelay.notnull().sum()
# Out:
# 964239

# %%
d.WeatherDelay.isnull().sum()
# Out:
# 4587558

# %%
d.columns
# Out:
# Index(['Year', 'DestCityMarketID', 'Dest', 'DestCityName', 'DestState',
#        'DestStateFips', 'DestStateName', 'DestWac', 'DestAirportSeqID',
#        'CRSDepTime', 'CRSArrTime', 'ArrTimeBlk', 'Cancelled', 'Diverted',
#        'Flights', 'DistanceGroup', 'DivAirportLandings', 'DepTimeBlk',
#        'DestAirportID', 'Distance', 'OriginStateName', 'OriginWac', 'Month',
#        'Day', 'Week', 'FlightDate', 'UniqueCarrier', 'AirlineID', 'Carrier',
#        'Quarter', 'Origin', 'OriginStateFips', 'OriginState', 'OriginCityName',
#        'FlightNum', 'OriginCityMarketID', 'OriginAirportSeqID',
#        'OriginAirportID', 'CRSElapsedTime', 'TailNum', 'DepTime', 'DepDelay',
#        'DepDelayMinutes', 'DepDel15', 'DepartureDelayGroups', 'WheelsOff',
#        'TaxiOut', 'TaxiIn', 'WheelsOn', 'ArrTime', 'ArrivalDelayGroups',
#        'ActualElapsedTime', 'AirTime', 'ArrDel15', 'ArrDelayMinutes',
#        'ArrDelay', 'SecurityDelay', 'LateAircraftDelay', 'WeatherDelay',
#        'CarrierDelay', 'NASDelay', 'CancellationCode'],
#       dtype='object')

# %%
d.CancellationCode.value_counts()
# Out:
# B    34465
# A    20279
# C    11091
# D       26
# Name: CancellationCode, dtype: int64

# %%
###

# %% [markdown]
# ### Taking only the columns relevant for the delay

# %%
columns = ['FlightNum','Year','Day','Month','Week','Origin','Dest','UniqueCarrier','Cancelled','ArrTime','DepTime','CRSArrTime','CRSDepTime','DepDel15','ArrDel15','CRSElapsedTime','ActualElapsedTime','ArrDelayMinutes','DepDelayMinutes','OriginCityName','DestCityName','Distance']

# %%
len(columns)
# Out:
# 22

# %%
dt = d[columns]
dt.shape
# Out:
# (5617658, 22)

# %%
len(dt[dt.Cancelled==1])
# Out:
# 65861

# %%
dt = dt[dt.Cancelled==0]

# %%
dt.isnull().sum().sort_values()
# Out:
# FlightNum                0
# OriginCityName           0
# DepDelayMinutes          0
# CRSElapsedTime           0
# DepDel15                 0
# CRSDepTime               0
# CRSArrTime               0
# DestCityName             0
# DepTime                  0
# UniqueCarrier            0
# Dest                     0
# Origin                   0
# Week                     0
# Month                    0
# Day                      0
# Year                     0
# Cancelled                0
# Distance                 0
# ArrTime               1983
# ArrDel15             13652
# ActualElapsedTime    13652
# ArrDelayMinutes      13652
# dtype: int64

# %% [markdown]
# ### Removing row having 'ArrTime','ArrDelayMinutes','ActualElapsedTime','ArrDelayMinutes' Nulls

# %%
# dt.loc[dt.Cancelled==1, ['DepTime']] = 0
# dt.loc[dt.Cancelled==1, ['DepDel15']] = 1
# dt = dt[dt.CRSElapsedTime.notnull()]

# %%
dt = dt[(dt.ArrTime.notnull()) & (dt.ActualElapsedTime.notnull())]

# %%
dt.isnull().sum().sort_values()
# Out:
# FlightNum            0
# OriginCityName       0
# DepDelayMinutes      0
# ArrDelayMinutes      0
# ActualElapsedTime    0
# CRSElapsedTime       0
# ArrDel15             0
# DepDel15             0
# CRSDepTime           0
# CRSArrTime           0
# DepTime              0
# ArrTime              0
# Cancelled            0
# UniqueCarrier        0
# Dest                 0
# Origin               0
# Week                 0
# Month                0
# Day                  0
# Year                 0
# DestCityName         0
# Distance             0
# dtype: int64

# %%
dt.dtypes
# Out:
# FlightNum              int64
# Year                   int64
# Day                    int64
# Month                  int64
# Week                   int64
# Origin                object
# Dest                  object
# UniqueCarrier         object
# Cancelled            float64
# ArrTime              float64
# DepTime              float64
# CRSArrTime             int64
# CRSDepTime             int64
# DepDel15             float64
# ArrDel15             float64
# CRSElapsedTime       float64
# ActualElapsedTime    float64
# ArrDelayMinutes      float64
# DepDelayMinutes      float64
# OriginCityName        object
# DestCityName          object
# Distance             float64
# dtype: object

# %%
dt[['Cancelled','ArrTime','DepTime','DepDel15','ArrDel15',
    'CRSElapsedTime','ActualElapsedTime','ArrDelayMinutes','DepDelayMinutes']]=dt[['Cancelled',
                                                                                   'ArrTime','DepTime','DepDel15','ArrDel15','CRSElapsedTime','ActualElapsedTime','ArrDelayMinutes','DepDelayMinutes']].astype(int)

# %%
dt.Cancelled.unique()
# Out:
# array([0])

# %% [markdown]
# ### Mapping from the LOOKUP tables

# %%
# # Mappping Day number to name
# days = {1:'Monday',2:'Tuesday',3:'Wedsday',4:'Thursday',5:'Friday',6:'Saturday',7:'Sunday'}

# df['Day'] = df['DayOfWeek'].apply(lambda x: days[x])

# %%
cancel = pd.read_csv(cur_path+'/Lookup/CancellationCode.csv', low_memory=False)
airport = pd.read_csv(cur_path+'/Lookup/AirportID.csv', low_memory=False)
carrier = pd.read_csv(cur_path+'/Lookup/UniqueCarrier.csv', low_memory=False)
origin = pd.read_csv(cur_path+'/Lookup/Origin.csv', low_memory=False)

cancel_dict = cancel.set_index('Code').T.to_dict('list')
origin_dict = origin.set_index('Code').T.to_dict('list')
airport_dict = airport.set_index('Code').T.to_dict('list')
carrier_dict = carrier.set_index('Code').T.to_dict('list')

# %%
#df['day'] = df['DayOfWeek'].apply(lambda x: days[x])

# %% [markdown]
# ### Adding new columns to differentiate flights felayed and ontime flights

# %%
dt['Flight_Status'] = 0
dt.loc[dt.DepDel15==1.0 ,'Flight_Status'] = 1
dt.loc[dt.ArrDel15==1.0,'Flight_Status'] = 1
dt['Flight_Status'] = dt['Flight_Status'].astype(int)

# %%
dt.isnull().sum()
# Out:
# FlightNum            0
# Year                 0
# Day                  0
# Month                0
# Week                 0
# Origin               0
# Dest                 0
# UniqueCarrier        0
# Cancelled            0
# ArrTime              0
# DepTime              0
# CRSArrTime           0
# CRSDepTime           0
# DepDel15             0
# ArrDel15             0
# CRSElapsedTime       0
# ActualElapsedTime    0
# ArrDelayMinutes      0
# DepDelayMinutes      0
# OriginCityName       0
# DestCityName         0
# Distance             0
# Flight_Status        0
# dtype: int64

# %% [markdown]
# ### Removing Outliers

# %%
dt.shape
# Out:
# (5538145, 23)

# %%
dt[dt.DepDelayMinutes>1350].shape
# Out:
# (48, 23)

# %%
dt[dt.ArrDelayMinutes>1400].shape
# Out:
# (41, 23)

# %%
dd =dt

# %%
#dd.DepDelayMinutes.fillna(0, inplace=True)

# %%
dd = dd[dd.DepDelayMinutes<1350]

# %%
dd = dd[dd.ArrDelayMinutes<1400]
dd.shape
# Out:
# (5538095, 23)

# %%
dd.Cancelled.unique()
# Out:
# array([0])

# %%
dd = dd[~((dd['Month'] == 1) & (dd['ArrDelayMinutes']>1320))]
dd = dd[~((dd['Month'] == 2) & (dd['ArrDelayMinutes']>1220))]
dd = dd[~((dd['Month'] == 3) & (dd['ArrDelayMinutes']>1220))]
dd = dd[~((dd['Month'] == 5) & (dd['ArrDelayMinutes']>1500))]
dd = dd[~((dd['Month'] == 6) & (dd['ArrDelayMinutes']>1200))]
dd = dd[~((dd['Month'] == 7) & (dd['ArrDelayMinutes']>1350))]
dd = dd[~((dd['Month'] == 9) & (dd['ArrDelayMinutes']>1120))]
dd = dd[~((dd['Month'] == 9) & (dd['ArrDelayMinutes']>1020))]
dd = dd[~((dd['Month'] == 10) & (dd['ArrDelayMinutes']>1270))]
dd = dd[~((dd['Month'] == 11) & (dd['ArrDelayMinutes']>1200))]
dd = dd[~((dd['Month'] == 12) & (dd['ArrDelayMinutes']>1350))]

# %%
dd.shape
# Out:
# (5538054, 23)

# %%
#dd[(dd.Month==11) & (dd.DepDelayMinutes>1100)]

# %%
dd = dd[~((dd['Month'] == 2) & (dd['DepDelayMinutes']>1220))]
dd = dd[~((dd['Month'] == 4) & (dd['DepDelayMinutes']>1220))]
dd = dd[~((dd['Month'] == 5) & (dd['DepDelayMinutes']>1200))]
dd = dd[~((dd['Month'] == 10) & (dd['DepDelayMinutes']>1210))]
dd = dd[~((dd['Month'] == 11) & (dd['DepDelayMinutes']>1100))]
dd = dd[~((dd['Month'] == 12) & (dd['DepDelayMinutes']>1350))]

# %%
dd.shape
# Out:
# (5538041, 22)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()

sns.lmplot(x='Month', y='DepDelayMinutes', data=dd, fit_reg=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()

sns.lmplot(x='Month', y='ArrDelayMinutes', data=dd, fit_reg=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()

sns.lmplot(x='Month', y='ArrDelayMinutes', data=dt, fit_reg=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()

sns.lmplot(x='Month', y='DepDelayMinutes', data=dt, fit_reg=False)
plt.show()

# %%
#dd.to_csv(cur_path+'/Data2016_Cleaned.csv', index = False)

# %%
dd.isnull().sum().sort_values()
# Out:
# FlightNum            0
# DestCityName         0
# OriginCityName       0
# DepDelayMinutes      0
# ArrDelayMinutes      0
# ActualElapsedTime    0
# CRSElapsedTime       0
# ArrDel15             0
# DepDel15             0
# CRSDepTime           0
# Distance             0
# CRSArrTime           0
# ArrTime              0
# Cancelled            0
# UniqueCarrier        0
# Dest                 0
# Origin               0
# Week                 0
# Month                0
# Day                  0
# Year                 0
# DepTime              0
# Flight_Status        0
# dtype: int64

# %% [markdown]
# # DATA CLEANING 2017

# %%
df1 = pd.read_csv(open(cur_path+'/Data2017_Uncleaned.csv','rU'), encoding='utf-8')
df1.shape
# Out:
# (4276457, 109)

# %%
missing_data1 = df1.isnull().sum().to_frame(name='Missing_Count').reset_index()
missing_data1['Missing_percent'] = (missing_data1['Missing_Count']/df1.shape[0])*100
missing_data1 = missing_data1.sort_values(by='Missing_percent', axis=0, ascending=True)
features1 = missing_data1['index'][(missing_data1.Missing_percent<99.38)]
len(features1)
d1 = df1[features1]

# %%
d1 = d1.rename(columns = {'DayofMonth':'Day','DayOfWeek':'Week'})

# %%
dt1= d1[columns]
dt1.shape
# Out:
# (4276457, 22)

# %%
dt1 = dt1[dt1.Cancelled==0]
dt1.shape
# Out:
# (4203809, 22)

# %%
dt1.isnull().sum().sort_values()
# Out:
# FlightNum                0
# OriginCityName           0
# DepDelayMinutes          0
# CRSElapsedTime           0
# DepDel15                 0
# CRSDepTime               0
# CRSArrTime               0
# DestCityName             0
# DepTime                  0
# UniqueCarrier            0
# Dest                     0
# Origin                   0
# Week                     0
# Month                    0
# Day                      0
# Year                     0
# Cancelled                0
# Distance                 0
# ArrTime               1572
# ArrDel15             10212
# ActualElapsedTime    10212
# ArrDelayMinutes      10212
# dtype: int64

# %%
dt1.loc[dt1.Cancelled==1, ['DepTime']] = 0
dt1.loc[dt1.Cancelled==1, ['DepDel15']] = 1
dt1 = dt1[dt1.CRSElapsedTime.notnull()]

# %%
dt1 = dt1[(dt.ArrTime.notnull()) & (dt1.ActualElapsedTime.notnull())]
dt1.shape
# Out:
# (4130702, 22)

# %%
dt1[['Cancelled','ArrTime','DepTime','DepDel15','ArrDel15',
    'CRSElapsedTime','ActualElapsedTime','ArrDelayMinutes','DepDelayMinutes']]=dt1[['Cancelled',
                                                                                   'ArrTime','DepTime','DepDel15','ArrDel15','CRSElapsedTime','ActualElapsedTime','ArrDelayMinutes','DepDelayMinutes']].astype(int)

# %%
#dt1.DepDelayMinutes.fillna(0, inplace=True)
dt1['Flight_Status'] = 0
dt1.loc[dt1.DepDel15==1.0 ,'Flight_Status'] = 1
dt1.loc[dt1.ArrDel15==1.0,'Flight_Status'] = 1
dt1['Flight_Status'] = dt1['Flight_Status'].astype(int)

# %%
dd1 = dt1
dd1.shape
# Out:
# (4130702, 23)

# %%
dd1 = dd1[~((dd1['Month'] == 1) & (dd1['ArrDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 3) & (dd1['ArrDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 9) & (dd1['ArrDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 5) & (dd1['ArrDelayMinutes']>1530))]
dd1 = dd1[~((dd1['Month'] == 6) & (dd1['ArrDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 7) & (dd1['ArrDelayMinutes']>1550))]
dd1 = dd1[~((dd1['Month'] == 9) & (dd1['ArrDelayMinutes']>1300))]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()

sns.lmplot(x='Month', y='ArrDelayMinutes', data=dd1, fit_reg=False)
plt.show()

# %%
dd1 = dd1[~((dd1['Month'] == 1) & (dd1['DepDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 3) & (dd1['DepDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 4) & (dd1['DepDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 5) & (dd1['DepDelayMinutes']>1520))]
dd1 = dd1[~((dd1['Month'] == 6) & (dd1['DepDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 7) & (dd1['DepDelayMinutes']>1500))]
dd1 = dd1[~((dd1['Month'] == 9) & (dd1['DepDelayMinutes']>1300))]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()

sns.lmplot(x='Month', y='DepDelayMinutes', data=dd1, fit_reg=False)
plt.show()

# %%
dd1.shape
# Out:
# (4130680, 23)

# %%
dd.shape
# Out:
# (5538041, 23)

# %%
dd.isnull().sum()
# Out:
# FlightNum            0
# Year                 0
# Day                  0
# Month                0
# Week                 0
# Origin               0
# Dest                 0
# UniqueCarrier        0
# Cancelled            0
# ArrTime              0
# DepTime              0
# CRSArrTime           0
# CRSDepTime           0
# DepDel15             0
# ArrDel15             0
# CRSElapsedTime       0
# ActualElapsedTime    0
# ArrDelayMinutes      0
# DepDelayMinutes      0
# OriginCityName       0
# DestCityName         0
# Distance             0
# Flight_Status        0
# dtype: int64

# %%
data = pd.concat([dd,dd1])

# %%
data.shape
# Out:
# (9668721, 23)

# %%
data.isnull().sum()
# Out:
# FlightNum            0
# Year                 0
# Day                  0
# Month                0
# Week                 0
# Origin               0
# Dest                 0
# UniqueCarrier        0
# Cancelled            0
# ArrTime              0
# DepTime              0
# CRSArrTime           0
# CRSDepTime           0
# DepDel15             0
# ArrDel15             0
# CRSElapsedTime       0
# ActualElapsedTime    0
# ArrDelayMinutes      0
# DepDelayMinutes      0
# OriginCityName       0
# DestCityName         0
# Distance             0
# Flight_Status        0
# dtype: int64

# %%
data.to_csv(cur_path+'/DataClean.csv',index = False)

# %%
#f = pd.concat([dd,dd1])

# %%
#f.isnull().sum().sort_values()

# %%
#data = f

# %%
# airports taken into consideration
airport = ['DFW', 'DTW', 'SEA', 'JFK', 'SJC', 'ORD', 'PHX', 'STL', 'LAX',
       'MCO', 'DEN', 'MIA', 'IAH','SLC', 'TUS','BOS', 'FLL', 'SFO', 'OGG', 'TPA', 'SNA', 'OKC', 'HNL',
       'PHL', 'LGA', 'RDU', 'DCA', 'RIC', 'ATL', 'LBB', 'CLT', 'ELP',
       'BNA', 'JAC', 'SMF', 'EWR', 'IAD', 'LIH', 'SJU', 'ABQ',
       'ORF', 'JAX', 'MSY','MCI', 'GUC', 'IND', 'PDX', 'BWI',
       'MSP', 'MKE', 'ONT', 'RSW', 'DSM', 'PSP',
       'EGE', 'PBI', 'SDF', 'PIT', 'DAY', 'STX', 'COS',
       'CMH', 'MTJ', 'HDN', 'BDL', 'MEM', 'CLE', 'HOU','OAK',
       'GEG', 'ANC', 'BUF', 'SYR', 'ALB', 'PVD','ILM', 'ICT',
       'PWM', 'GSO', 'CHS', 'MDT', 'BHM', 'ADQ', 'BRW', 'SCC',
       'JNU', 'KTN', 'YAK', 'CDV','PSG', 'WRG', 'OME',
       'OTZ', 'BUR', 'ADK', 'SWF', 'LGB', 'PSE', 'BQN', 'HPN',
       'SAV', 'SRQ', 'BTV', 'ORH','CVG', 'BIS', 'AVL', 'GRR',
       'FNT', 'MYR', 'JAN', 'FAR', 'PNS', 'AGS','LEX',
       'DAL', 'ATW', 'GPT', 'MLB', 'BZN', 'CHO', 'MSN', 'EYW',
       'TRI', 'LFT', 'ROA', 'ECP', 'VPS', 'XNA', 'EVV', 'AVP', 'MDW',
       'HSV', 'FAY', 'TYS', 'TLH', 'MSO','TTN',
       'PHF', 'FSD', 'LBE','BMI', 'CRW','PPG', 'IAG', 'ACT','SHV', 'FSM', 'MAF',
       'SAF', 'JLN', 'LRD', 'BRO', 'TYR', 'GJT', 'DLH',
       'SBA', 'ASE', 'IDA', 'RAP', 'FCA', 'LNK', 'AMA',
       'BFL', 'MLI', 'LSE', 'SBN', 'PSC','FLG', 'ISN', 'GFK',
       'GTF', 'MRY', 'MBS', 'SUN', 'TWF', 'SGF', 'CPR',
       'BTR', 'PBG', 'CRP', 'CID', 'SBP', 'RKS', 'CMX', 'MMH', 'PLN',
       'EKO', 'GCC', 'MFR', 'SMX', 'EUG', 'RST', 'TVC', 'SPI',
       'SGU', 'HLN', 'RDM', 'ACV', 'EAU', 'DVL', 'JMS', 'MKG', 'HYS',
       'COD', 'ITH', 'APN', 'ESC', 'BJI', 'MQT',
       'BGM', 'RHI', 'LWS', 'IMT', 'BRD', 'INL', 'PIH', 'GUM', 'HIB',
       'BTM', 'CDC', 'OTH', 'RDD', 'HRL', 'ISP', 'MHT', 'GNV',
       'MEI', 'PIB', 'BPT',  'AEX', 'TXK', 'ROW', 'CLL',
       'HOB', 'LCH', 'OAJ', 'ELM', 'VLD', 'MGM', 'BGR', 'GTR',
       'CSG', 'BQK', 'DHN', 'EWN', 'ABY', 'SPS', 'SJT', 'GGG',
       'ACK', 'MVY', 'HYA', 'GST', 'AKN', 'DLG', 'GCK', 'MHK',
       'ABI', 'GRI', 'EFD', 'PGD', 'SPN']

# %%
dt_both = data[data.Origin.isin(airport)]
dt_both = dt_both[dt_both.Dest.isin(airport)]

# %%
df_weather2016 = pd.read_csv(cur_path+'/weatherdata2016/weatherdata2016.csv', low_memory=False)
df_weather2017 = pd.read_csv(cur_path+'/weatherdata2017/weatherdata2017.csv', low_memory=False)

# %%
df_weather2016=df_weather2016.rename(columns = {'year':'Year','month':'Month','day':'Day'})
df_weather2017=df_weather2017.rename(columns = {'year':'Year','month':'Month','day':'Day'})
df_weather = pd.concat([df_weather2016,df_weather2017])

# %%
df_weather_origin = df_weather[['station', 'Year', 'Month', 'Day', 'Visibility', 'Wind', 'Precip']]
df_weather_origin.columns = ['Origin', 'Year', 'Month', 'Day', 'OriginVisibility', 'OriginWind', 'OriginPrecip']

# %%
result = dt_both.merge(df_weather_origin.drop_duplicates(subset=['Origin', 'Year','Month', 'Day']), how='left',on=['Origin', 'Year','Month', 'Day'])

# %%
result.isnull().sum().sort_values()
# Out:
# FlightNum                 0
# Flight_Status             0
# Distance                  0
# DestCityName              0
# OriginCityName            0
# DepDelayMinutes           0
# ArrDelayMinutes           0
# ActualElapsedTime         0
# CRSElapsedTime            0
# ArrDel15                  0
# DepDel15                  0
# CRSDepTime                0
# DepTime                   0
# ArrTime                   0
# Cancelled                 0
# UniqueCarrier             0
# Dest                      0
# Origin                    0
# Week                      0
# Month                     0
# Day                       0
# Year                      0
# CRSArrTime                0
# OriginWind           395343
# OriginVisibility     395343
# OriginPrecip         395343
# dtype: int64

# %%
final_combined =result
final_combined.OriginVisibility = final_combined.OriginVisibility.fillna((final_combined.OriginVisibility.fillna(method='ffill') +final_combined.OriginVisibility.fillna(method='bfill'))/2)
final_combined.OriginWind = final_combined.OriginWind.fillna((final_combined.OriginWind.fillna(method='ffill') +final_combined.OriginWind.fillna(method='bfill'))/2)
final_combined.OriginPrecip = final_combined.OriginPrecip.fillna((final_combined.OriginPrecip.fillna(method='ffill') +final_combined.OriginPrecip.fillna(method='bfill'))/2)

# %%
df_dec = final_combined.loc[(final_combined['Month']==9)]

# %%
mode_vis = df_dec.OriginVisibility.mode()[0]
mode_wind = df_dec.OriginWind.mode()[0]
mode_pre = df_dec.OriginPrecip.mode()[0]

# %%
final_combined.OriginVisibility = final_combined.OriginVisibility.fillna(mode_vis)
final_combined.OriginWind = final_combined.OriginWind.fillna(mode_wind)
final_combined.OriginPrecip = final_combined.OriginPrecip.fillna(mode_pre)

# %%
final_combined.isnull().sum().sort_values()
# Out:
# FlightNum            0
# OriginVisibility     0
# Flight_Status        0
# Distance             0
# DestCityName         0
# OriginCityName       0
# DepDelayMinutes      0
# ArrDelayMinutes      0
# ActualElapsedTime    0
# CRSElapsedTime       0
# ArrDel15             0
# DepDel15             0
# CRSDepTime           0
# CRSArrTime           0
# DepTime              0
# ArrTime              0
# Cancelled            0
# UniqueCarrier        0
# Dest                 0
# Origin               0
# Week                 0
# Month                0
# Day                  0
# Year                 0
# OriginWind           0
# OriginPrecip         0
# dtype: int64

# %%
final_combined.shape
# Out:
# (8006399, 26)

# %%
final_combined.columns
# Out:
# Index(['FlightNum', 'Year', 'Day', 'Month', 'Week', 'Origin', 'Dest',
#        'UniqueCarrier', 'Cancelled', 'ArrTime', 'DepTime', 'CRSArrTime',
#        'CRSDepTime', 'DepDel15', 'ArrDel15', 'CRSElapsedTime',
#        'ActualElapsedTime', 'ArrDelayMinutes', 'DepDelayMinutes',
#        'OriginCityName', 'DestCityName', 'Distance', 'Flight_Status',
#        'OriginVisibility', 'OriginWind', 'OriginPrecip'],
#       dtype='object')

# %%
final_combined.to_csv(cur_path+'/DataCLEAN.csv',index = False)

# %% [markdown]
# # FEATURES THAT ARE REQUIRED

# %%
del final_combined['ArrDel15']
del final_combined['ArrTime']
del final_combined['ActualElapsedTime']
del final_combined['ArrDelayMinutes']
del final_combined['DepDel15']
del final_combined['Cancelled']
del final_combined['DepTime']

# %%
final_combined.dtypes
# Out:
# FlightNum             int64
# Year                  int64
# Day                   int64
# Month                 int64
# Week                  int64
# Origin               object
# Dest                 object
# UniqueCarrier        object
# CRSArrTime            int64
# CRSDepTime            int64
# CRSElapsedTime        int64
# DepDelayMinutes       int64
# OriginCityName       object
# DestCityName         object
# Distance            float64
# Flight_Status         int64
# OriginVisibility    float64
# OriginWind          float64
# OriginPrecip        float64
# dtype: object

# %%
final_combined[['CRSElapsedTime','DepDelayMinutes','Distance','OriginVisibility','OriginWind','OriginPrecip']]= final_combined[['CRSElapsedTime','DepDelayMinutes','Distance','OriginVisibility','OriginWind','OriginPrecip']].astype(int)

# %%
final_combined['CRSDep_hour'] = final_combined['CRSDepTime'].apply(lambda x: str(x)[:-2])
final_combined['CRSDep_min'] = final_combined['CRSDepTime'].apply(lambda x: str(x)[2:4])
final_combined['CRSArr_hour'] = final_combined['CRSArrTime'].apply(lambda x: str(x)[:-2])
final_combined['CRSArr_min'] = final_combined['CRSArrTime'].apply(lambda x: str(x)[2:4])
final_combined = final_combined.replace('', 0)

# %%
final_combined.to_csv(cur_path+'/Data_for_Models.csv',index = False)

# %%
len(final_combined.columns)
# Out:
# 23

# %%
final_combined.columns
# Out:
# Index(['FlightNum', 'Year', 'Day', 'Month', 'Week', 'Origin', 'Dest',
#        'UniqueCarrier', 'CRSArrTime', 'CRSDepTime', 'CRSElapsedTime',
#        'DepDelayMinutes', 'OriginCityName', 'DestCityName', 'Distance',
#        'Flight_Status', 'OriginVisibility', 'OriginWind', 'OriginPrecip',
#        'CRSDep_hour', 'CRSDep_min', 'CRSArr_hour', 'CRSArr_min'],
#       dtype='object')

# %%
# For Prediction

# %%
cols = ['Year', 'Day', 'Month', 'Week', 'Origin', 'Dest', 'UniqueCarrier',
       'CRSElapsedTime', 'Distance', 'OriginVisibility', 'OriginWind',
       'OriginPrecip', 'CRSDep_hour', 'CRSDep_min', 'CRSArr_hour',
       'CRSArr_min','Flight_Status','DepDelayMinutes']

# %%
pr = final_combined[cols]

# %%
pr = pr[pr.Flight_Status==1]
pr = pr[pr.DepDelayMinutes != 0]

# %%
pr.shape
# Out:
# (1606792, 18)

# %%
for i in final_combined.columns.tolist():
    if i not in cols:
        print(i)
# Out:
# FlightNum
# CRSArrTime
# CRSDepTime
# OriginCityName
# DestCityName

# %%
pr.to_csv(cur_path+'/Data_for_Prediction.csv',index = False)
