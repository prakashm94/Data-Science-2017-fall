# %% [markdown]
# # Data Cleaning

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
color = sns.color_palette()

# %%
cur_path = '/Users/sonalichaudhari/Desktop/ADS_Project/Data'

# %%
d1 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_1/On_Time_On_Time_Performance_2017_1.csv', low_memory=False)
d2 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_2/On_Time_On_Time_Performance_2017_2.csv', low_memory=False)
d3 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_3/On_Time_On_Time_Performance_2017_3.csv', low_memory=False)
d4 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_4/On_Time_On_Time_Performance_2017_4.csv', low_memory=False)
d5 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_5/On_Time_On_Time_Performance_2017_5.csv', low_memory=False)
d6 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_6/On_Time_On_Time_Performance_2017_6.csv', low_memory=False)
d7 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_7/On_Time_On_Time_Performance_2017_7.csv', low_memory=False)
d8 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_8/On_Time_On_Time_Performance_2017_8.csv', low_memory=False)
d9 = pd.read_csv(cur_path+'/On_Time_On_Time_Performance_2017_9/On_Time_On_Time_Performance_2017_9.csv', low_memory=False)

# %%
df = pd.concat([d1, d2, d3, d4, d5, d6, d7, d8, d9])

# %%
df.head()
del df['Unnamed: 109']

# %%
df.shape
# Out:
# (4276457, 109)

# %%
missing_data = df.isnull().sum().to_frame(name='Missing_Count').reset_index()
missing_data['Missing_percent'] = (missing_data['Missing_Count']/df.shape[0])*100
missing_data = missing_data.sort_values(by='Missing_percent', axis=0, ascending=True)
features = missing_data['index'][(missing_data.Missing_percent <30)]

# %%
fig, ax = plt.subplots(figsize=(20,40))
ax.barh(range(df.shape[1]), missing_data.Missing_percent.values, align='center',color='Red')

ax.set_yticks(range(df.shape[1]))
ax.set_yticklabels(missing_data['index'].values,rotation =0,linespacing =20, fontsize =10)
ax.invert_yaxis()  

ax.set_xlabel('Percentage of Missing Data in each Column',fontsize=20, color='red')
ax.set_ylabel('Columns',fontsize=14, color='red')
ax.set_title('Missing Data',fontsize=16, color='red')

#plt.show()

# %%
df[['ArrDel15','DepDel15']].isnull().sum()
# Out:
# ArrDel15    82860
# DepDel15    70672
# dtype: int64

# %%
df['Cancelled'].unique()
# Out:
# array([ 0.,  1.])

# %%
df['Flight_Status'] = np.where(df['ArrDel15']==1.0,1,0)
df['Flight_Status'] = np.where(df['DepDel15']==1.0,1,0)
df.loc[df.Cancelled==1.0, ['Flight_Status']] = 1
df['Flight_Status'] = df['Flight_Status'].astype(int)
df['Status'] = np.where(df['Flight_Status']==1,'Delayed','On Time')

# %%
plt.rc("figure", figsize=(18, 6))
c = df.groupby('Status')
c['Status'].count().plot(kind='bar', color =['red', 'green'])
plt.title('Flight Status',fontsize=30,fontweight="bold", va='bottom')
plt.ylabel('Count',fontsize=15,fontweight="bold")
print(c['Status'].count())
plt.show()
# Out:
# Status
# Delayed     877417
# On Time    3399040
# Name: Status, dtype: int64

# %%
s = df[df['Status']=='Delayed'].groupby("Cancelled")
s['Cancelled'].count().plot(kind='bar', color =['red', 'green'])
plt.title('Delayed Flight Status: Delayed/Cancelled',fontsize=30,fontweight="bold", va='bottom')
plt.ylabel('Count',fontsize=15,fontweight="bold")
print(c['Status'].count())
plt.show()
# Out:
# Status
# Delayed     877417
# On Time    3399040
# Name: Status, dtype: int64

# %%
days = {1:'Monday',2:'Tuesday',3:'Wedsday',4:'Thursday',5:'Friday',6:'Saturday',7:'Sunday'}

df['day'] = df['DayOfWeek'].apply(lambda x: days[x])

# %%
df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2017        1      1          17          2  2017-01-17            AA
# 1       2017        1      1          18          3  2017-01-18            AA
# 2       2017        1      1          19          4  2017-01-19            AA
# 3       2017        1      1          20          5  2017-01-20            AA
# 4       2017        1      1          21          6  2017-01-21            AA
# 5       2017        1      1          22          7  2017-01-22            AA
# 6       2017        1      1          23          1  2017-01-23            AA
# 7       2017        1      1          24          2  2017-01-24            AA
# 8       2017        1      1          25          3  2017-01-25            AA
# 9       2017        1      1          26          4  2017-01-26            AA
# 10      2017        1      1          27          5  2017-01-27            AA
# 11      2017        1      1          28          6  2017-01-28            AA
# 12      2017        1      1          29          7  2017-01-29            AA
# 13      2017        1      1          30          1  2017-01-30            AA
# 14      2017        1      1          31          2  2017-01-31            AA
# 15      2017        1      1          11          3  2017-01-11            AA
# 16      2017        1      1          12          4  2017-01-12            AA
# 17      2017        1      1          13          5  2017-01-13            AA
# 18      2017        1      1          14          6  2017-01-14            AA
# 19      2017        1      1          18          3  2017-01-18            AA
# 20      2017        1      1          19          4  2017-01-19            AA
# 21      2017        1      1          20          5  2017-01-20            AA
# 22      2017        1      1          21          6  2017-01-21            AA
# 23      2017        1      1          22          7  2017-01-22            AA
# 24      2017        1      1          25          3  2017-01-25            AA
# 25      2017        1      1          26          4  2017-01-26            AA
# 26      2017        1      1          27          5  2017-01-27            AA
# 27      2017        1      1          28          6  2017-01-28            AA
# 28      2017        1      1          29          7  2017-01-29            AA
# 29      2017        1      1           6          5  2017-01-06            AA
# ...      ...      ...    ...         ...        ...         ...           ...
# 458697  2017        3      9          25          1  2017-09-25            B6
# 458698  2017        3      9          25          1  2017-09-25            B6
# 458699  2017        3      9          25          1  2017-09-25            B6
# 458700  2017        3      9          25          1  2017-09-25            B6
# 458701  2017        3      9          25          1  2017-09-25            B6
# 458702  2017        3      9          25          1  2017-09-25            B6
# 458703  2017        3      9          25          1  2017-09-25            B6
# 458704  2017        3      9          25          1  2017-09-25            B6
# 458705  2017        3      9          25          1  2017-09-25            B6
# 458706  2017        3      9          25          1  2017-09-25            B6
# 458707  2017        3      9          25          1  2017-09-25            B6
# 458708  2017        3      9          25          1  2017-09-25            B6
# 458709  2017        3      9          25          1  2017-09-25            B6
# 458710  2017        3      9          25          1  2017-09-25            B6
# 458711  2017        3      9          25          1  2017-09-25            B6
# 458712  2017        3      9          25          1  2017-09-25            B6
# 458713  2017        3      9          25          1  2017-09-25            B6
# 458714  2017        3      9          25          1  2017-09-25            B6
# 458715  2017        3      9          25          1  2017-09-25            B6
# 458716  2017        3      9          25          1  2017-09-25            B6
# 458717  2017        3      9          25          1  2017-09-25            B6
# 458718  2017        3      9          25          1  2017-09-25            B6
# 458719  2017        3      9          25          1  2017-09-25            B6
# 458720  2017        3      9          25          1  2017-09-25            B6
# 458721  2017        3      9          25          1  2017-09-25            B6
# 458722  2017        3      9          25          1  2017-09-25            B6
# 458723  2017        3      9          25          1  2017-09-25            B6
# 458724  2017        3      9          25          1  2017-09-25            B6
# 458725  2017        3      9          25          1  2017-09-25            B6
# 458726  2017        3      9          25          1  2017-09-25            B6
#
#         AirlineID Carrier TailNum   ...    Div5AirportSeqID  Div5WheelsOn  \
# 0           19805      AA  N583AA   ...                 NaN           NaN
# 1           19805      AA  N544AA   ...                 NaN           NaN
# 2           19805      AA  N553AA   ...                 NaN           NaN
# 3           19805      AA  N191AA   ...                 NaN           NaN
# 4           19805      AA  N170AA   ...                 NaN           NaN
# 5           19805      AA  N179AA   ...                 NaN           NaN
# 6           19805      AA  N579AA   ...                 NaN           NaN
# 7           19805      AA  N583AA   ...                 NaN           NaN
# 8           19805      AA  N167AA   ...                 NaN           NaN
# 9           19805      AA  N551AA   ...                 NaN           NaN
# 10          19805      AA  N919AA   ...                 NaN           NaN
# 11          19805      AA  N542AA   ...                 NaN           NaN
# 12          19805      AA  N559AA   ...                 NaN           NaN
# 13          19805      AA  N921AA   ...                 NaN           NaN
# 14          19805      AA  N972AA   ...                 NaN           NaN
# 15          19805      AA  N185AA   ...                 NaN           NaN
# 16          19805      AA  N970AA   ...                 NaN           NaN
# 17          19805      AA  N199AA   ...                 NaN           NaN
# 18          19805      AA  N919AA   ...                 NaN           NaN
# 19          19805      AA  N190AA   ...                 NaN           NaN
# 20          19805      AA  N553AA   ...                 NaN           NaN
# 21          19805      AA  N191AA   ...                 NaN           NaN
# 22          19805      AA  N170AA   ...                 NaN           NaN
# 23          19805      AA  N179AA   ...                 NaN           NaN
# 24          19805      AA  N167AA   ...                 NaN           NaN
# 25          19805      AA  N551AA   ...                 NaN           NaN
# 26          19805      AA  N919AA   ...                 NaN           NaN
# 27          19805      AA  N510AA   ...                 NaN           NaN
# 28          19805      AA  N559AA   ...                 NaN           NaN
# 29          19805      AA  N554AA   ...                 NaN           NaN
# ...           ...     ...     ...   ...                 ...           ...
# 458697      20409      B6  N238JB   ...                 NaN           NaN
# 458698      20409      B6  N556JB   ...                 NaN           NaN
# 458699      20409      B6  N648JB   ...                 NaN           NaN
# 458700      20409      B6  N712JB   ...                 NaN           NaN
# 458701      20409      B6  N605JB   ...                 NaN           NaN
# 458702      20409      B6  N368JB   ...                 NaN           NaN
# 458703      20409      B6  N267JB   ...                 NaN           NaN
# 458704      20409      B6  N638JB   ...                 NaN           NaN
# 458705      20409      B6  N635JB   ...                 NaN           NaN
# 458706      20409      B6  N552JB   ...                 NaN           NaN
# 458707      20409      B6  N258JB   ...                 NaN           NaN
# 458708      20409      B6  N265JB   ...                 NaN           NaN
# 458709      20409      B6  N292JB   ...                 NaN           NaN
# 458710      20409      B6  N353JB   ...                 NaN           NaN
# 458711      20409      B6  N956JB   ...                 NaN           NaN
# 458712      20409      B6  N593JB   ...                 NaN           NaN
# 458713      20409      B6  N580JB   ...                 NaN           NaN
# 458714      20409      B6  N580JB   ...                 NaN           NaN
# 458715      20409      B6  N729JB   ...                 NaN           NaN
# 458716      20409      B6  N621JB   ...                 NaN           NaN
# 458717      20409      B6  N583JB   ...                 NaN           NaN
# 458718      20409      B6  N639JB   ...                 NaN           NaN
# 458719      20409      B6  N603JB   ...                 NaN           NaN
# 458720      20409      B6  N506JB   ...                 NaN           NaN
# 458721      20409      B6  N216JB   ...                 NaN           NaN
# 458722      20409      B6  N216JB   ...                 NaN           NaN
# 458723      20409      B6  N651JB   ...                 NaN           NaN
# 458724      20409      B6  N265JB   ...                 NaN           NaN
# 458725      20409      B6  N298JB   ...                 NaN           NaN
# 458726      20409      B6  N789JB   ...                 NaN           NaN
#
#         Div5TotalGTime  Div5LongestGTime Div5WheelsOff Div5TailNum  \
# 0                  NaN               NaN           NaN         NaN
# 1                  NaN               NaN           NaN         NaN
# 2                  NaN               NaN           NaN         NaN
# 3                  NaN               NaN           NaN         NaN
# 4                  NaN               NaN           NaN         NaN
# 5                  NaN               NaN           NaN         NaN
# 6                  NaN               NaN           NaN         NaN
# 7                  NaN               NaN           NaN         NaN
# 8                  NaN               NaN           NaN         NaN
# 9                  NaN               NaN           NaN         NaN
# 10                 NaN               NaN           NaN         NaN
# 11                 NaN               NaN           NaN         NaN
# 12                 NaN               NaN           NaN         NaN
# 13                 NaN               NaN           NaN         NaN
# 14                 NaN               NaN           NaN         NaN
# 15                 NaN               NaN           NaN         NaN
# 16                 NaN               NaN           NaN         NaN
# 17                 NaN               NaN           NaN         NaN
# 18                 NaN               NaN           NaN         NaN
# 19                 NaN               NaN           NaN         NaN
# 20                 NaN               NaN           NaN         NaN
# 21                 NaN               NaN           NaN         NaN
# 22                 NaN               NaN           NaN         NaN
# 23                 NaN               NaN           NaN         NaN
# 24                 NaN               NaN           NaN         NaN
# 25                 NaN               NaN           NaN         NaN
# 26                 NaN               NaN           NaN         NaN
# 27                 NaN               NaN           NaN         NaN
# 28                 NaN               NaN           NaN         NaN
# 29                 NaN               NaN           NaN         NaN
# ...                ...               ...           ...         ...
# 458697             NaN               NaN           NaN         NaN
# 458698             NaN               NaN           NaN         NaN
# 458699             NaN               NaN           NaN         NaN
# 458700             NaN               NaN           NaN         NaN
# 458701             NaN               NaN           NaN         NaN
# 458702             NaN               NaN           NaN         NaN
# 458703             NaN               NaN           NaN         NaN
# 458704             NaN               NaN           NaN         NaN
# 458705             NaN               NaN           NaN         NaN
# 458706             NaN               NaN           NaN         NaN
# 458707             NaN               NaN           NaN         NaN
# 458708             NaN               NaN           NaN         NaN
# 458709             NaN               NaN           NaN         NaN
# 458710             NaN               NaN           NaN         NaN
# 458711             NaN               NaN           NaN         NaN
# 458712             NaN               NaN           NaN         NaN
# 458713             NaN               NaN           NaN         NaN
# 458714             NaN               NaN           NaN         NaN
# 458715             NaN               NaN           NaN         NaN
# 458716             NaN               NaN           NaN         NaN
# 458717             NaN               NaN           NaN         NaN
# 458718             NaN               NaN           NaN         NaN
# 458719             NaN               NaN           NaN         NaN
# 458720             NaN               NaN           NaN         NaN
# 458721             NaN               NaN           NaN         NaN
# 458722             NaN               NaN           NaN         NaN
# 458723             NaN               NaN           NaN         NaN
# 458724             NaN               NaN           NaN         NaN
# 458725             NaN               NaN           NaN         NaN
# 458726             NaN               NaN           NaN         NaN
#
#        Flight_Status   Status       day   index
# 0                  0  On Time   Tuesday       1
# 1                  0  On Time   Wedsday       2
# 2                  0  On Time  Thursday       3
# 3                  1  Delayed    Friday       4
# 4                  0  On Time    Satday       5
# 5                  1  Delayed    Sunday       6
# 6                  0  On Time    Monday       7
# 7                  0  On Time   Tuesday       8
# 8                  0  On Time   Wedsday       9
# 9                  0  On Time  Thursday      10
# 10                 0  On Time    Friday      11
# 11                 0  On Time    Satday      12
# 12                 0  On Time    Sunday      13
# 13                 0  On Time    Monday      14
# 14                 0  On Time   Tuesday      15
# 15                 0  On Time   Wedsday      16
# 16                 0  On Time  Thursday      17
# 17                 0  On Time    Friday      18
# 18                 0  On Time    Satday      19
# 19                 0  On Time   Wedsday      20
# 20                 0  On Time  Thursday      21
# 21                 0  On Time    Friday      22
# 22                 0  On Time    Satday      23
# 23                 1  Delayed    Sunday      24
# 24                 0  On Time   Wedsday      25
# 25                 0  On Time  Thursday      26
# 26                 0  On Time    Friday      27
# 27                 0  On Time    Satday      28
# 28                 0  On Time    Sunday      29
# 29                 0  On Time    Friday      30
# ...              ...      ...       ...     ...
# 458697             0  On Time    Monday  458698
# 458698             1  Delayed    Monday  458699
# 458699             1  Delayed    Monday  458700
# 458700             0  On Time    Monday  458701
# 458701             0  On Time    Monday  458702
# 458702             0  On Time    Monday  458703
# 458703             0  On Time    Monday  458704
# 458704             0  On Time    Monday  458705
# 458705             0  On Time    Monday  458706
# 458706             0  On Time    Monday  458707
# 458707             1  Delayed    Monday  458708
# 458708             0  On Time    Monday  458709
# 458709             0  On Time    Monday  458710
# 458710             0  On Time    Monday  458711
# 458711             0  On Time    Monday  458712
# 458712             0  On Time    Monday  458713
# 458713             0  On Time    Monday  458714
# 458714             0  On Time    Monday  458715
# 458715             0  On Time    Monday  458716
# 458716             1  Delayed    Monday  458717
# 458717             0  On Time    Monday  458718
# 458718             0  On Time    Monday  458719
# 458719             0  On Time    Monday  458720
# 458720             0  On Time    Monday  458721
# 458721             0  On Time    Monday  458722
# 458722             1  Delayed    Monday  458723
# 458723             0  On Time    Monday  458724
# 458724             0  On Time    Monday  458725
# 458725             0  On Time    Monday  458726
# 458726             0  On Time    Monday  458727
#
# [4276457 rows x 113 columns]

# %%
df = df.reset_index()
df['index'] = df.index +1
df=df.rename(columns = {'index':'id'})
df= df.set_index('id')

# %%
tps = df.pivot_table(values=['index'], index='DayOfWeek',columns='Status',aggfunc='sum')

tps = tps.div(tps.sum(1), axis=0)
tps.plot(kind='bar', stacked=True)
plt.show()
tps
# Out:
#               index
# Status      Delayed   On Time
# DayOfWeek
# 1          0.232469  0.767531
# 2          0.195562  0.804438
# 3          0.199784  0.800216
# 4          0.229509  0.770491
# 5          0.239105  0.760895
# 6          0.183843  0.816157
# 7          0.200158  0.799842

# %%
df.groupby('Dest')['index'].count().sort_values(ascending=0).plot(kind='bar')
plt.xlabel('Loan Status')
plt.ylabel('Loan Amount')
plt.title('Loan amount and their current status',size=22,color="black")
plt.show()

# %%
#df['Dest'].value_counts().to_frame().reset_index('Count')
df.groupby('Dest')['index].count()
# Out:
#   File "<ipython-input-193-195ef5f53db0>", line 2
#     df.groupby('Dest')['index].count()
#                                       ^
# SyntaxError: EOL while scanning string literal

# %%
df[['index','Dest']].groupby("Dest").count().reset_index().sort('index', ascending = False)[:10]
# Out:
#     Dest   index
# 20   ATL  278211
# 222  ORD  202268
# 80   DEN  168366
# 170  LAX  161128
# 81   DFW  136477
# 272  SFO  129647
# 234  PHX  117199
# 168  LAS  114332
# 271  SEA  103586
# 210  MSP  101138
