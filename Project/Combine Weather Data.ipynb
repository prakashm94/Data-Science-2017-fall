# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import csv

# %%
cur_path = '/Users/madhu/Documents/NEU/Fall 2017/ADS Class'

# %%
d1_2016 = pd.read_csv(cur_path+'/weatherdata2016/BOS2016.csv', low_memory=False)
d2_2016 = pd.read_csv(cur_path+'/weatherdata2016/DEN2016.csv', low_memory=False)
d3_2016 = pd.read_csv(cur_path+'/weatherdata2016/DFW2016.csv', low_memory=False)
d4_2016 = pd.read_csv(cur_path+'/weatherdata2016/EWR2016.csv', low_memory=False)
d5_2016 = pd.read_csv(cur_path+'/weatherdata2016/IAH2016.csv', low_memory=False)
d6_2016 = pd.read_csv(cur_path+'/weatherdata2016/LGA2016.csv', low_memory=False)
d7_2016 = pd.read_csv(cur_path+'/weatherdata2016/ORD2016.csv', low_memory=False)
d8_2016 = pd.read_csv(cur_path+'/weatherdata2016/PHL2016.csv', low_memory=False)
d9_2016 = pd.read_csv(cur_path+'/weatherdata2016/SFO2016.csv', low_memory=False)
d10_2016 = pd.read_csv(cur_path+'/weatherdata2016/JFK2016.csv', low_memory=False)
d10_2016 = pd.read_csv(cur_path+'/weatherdata2016/JFK2016.csv', low_memory=False)

# %%
d2_2016.loc[(d2_2016['month']==2)]
# Out:
#    station  year  month  day  Visibility  Wind  Precip
# 31     DEN  2016      2    1          18     4     0.0
# 32     DEN  2016      2    2          16     0     0.0
# 33     DEN  2016      2    3          18     1     0.0
# 34     DEN  2016      2    4          19     3     0.0
# 35     DEN  2016      2    5          19     5     0.0
# 36     DEN  2016      2    6          19     2     0.0
# 37     DEN  2016      2    8          16     3     0.0
# 38     DEN  2016      2    9          17     6     0.0
# 39     DEN  2016      2   10          18     5     0.0
# 40     DEN  2016      2   11          17     2     0.0
# 41     DEN  2016      2   12          16     4     0.0
# 42     DEN  2016      2   13          16     4     0.0
# 43     DEN  2016      2   14          18     3     0.0
# 44     DEN  2016      2   15          14     4     0.0
# 45     DEN  2016      2   16          18     1     0.0
# 46     DEN  2016      2   17          16     3     0.0
# ...

# %%
d1_2017 = pd.read_csv(cur_path+'/weatherdata2017/BOS2017.csv', low_memory=False)
d2_2017 = pd.read_csv(cur_path+'/weatherdata2017/DEN2017.csv', low_memory=False)
d3_2017 = pd.read_csv(cur_path+'/weatherdata2017/DFW2017.csv', low_memory=False)
d4_2017 = pd.read_csv(cur_path+'/weatherdata2017/EWR2017.csv', low_memory=False)
d5_2017 = pd.read_csv(cur_path+'/weatherdata2017/IAH2017.csv', low_memory=False)
d6_2017 = pd.read_csv(cur_path+'/weatherdata2017/LGA2017.csv', low_memory=False)
d7_2017 = pd.read_csv(cur_path+'/weatherdata2017/ORD2017.csv', low_memory=False)
d8_2017 = pd.read_csv(cur_path+'/weatherdata2017/PHL2017.csv', low_memory=False)
d9_2017 = pd.read_csv(cur_path+'/weatherdata2017/SFO2017.csv', low_memory=False)
d10_2017 = pd.read_csv(cur_path+'/weatherdata2017/JFK2017.csv', low_memory=False)

# %%
df_2016_combined = pd.concat([d1_2016, d2_2016, d3_2016, d4_2016, d5_2016, d6_2016, d7_2016, d8_2016, d9_2016, d10_2016])

# %%
df_2017_combined = pd.concat([d1_2017, d2_2017, d3_2017, d4_2017, d5_2017, d6_2017, d7_2017, d8_2017, d9_2017, d10_2017])

# %%
combined_weather_data = pd.concat([df_2016_combined, df_2017_combined])

# %%
combined_weather_data.dtypes
# Out:
# station        object
# year            int64
# month           int64
# day             int64
# Visibility      int64
# Wind            int64
# Precip        float64
# dtype: object

# %%
combined_weather_data.columns = ['station', 'Year', 'Month', 'DayofMonth', 'Visibility', 'Wind', 'Precip']

# %%
combined_weather_data.to_csv(cur_path+'/Top10WeatherData.csv',index=False)

# %%
combined_weather_data
# Out:
#     station  Year  Month  DayofMonth  Visibility  Wind  Precip
# 0       BOS  2016      1           1          11     3    0.00
# 1       BOS  2016      1           2          10     3    0.00
# 2       BOS  2016      1           3           5     3    0.75
# 3       BOS  2016      1           4           8     5    0.08
# 4       BOS  2016      1           5           7     7    0.02
# 5       BOS  2016      1           6           6     5    0.75
# 6       BOS  2016      1           7           7     5    0.12
# 7       BOS  2016      1           8           8     3    0.00
# 8       BOS  2016      1           9           8     1    0.00
# 9       BOS  2016      1          10           7     4    0.08
# 10      BOS  2016      1          11           7     8    0.00
# 11      BOS  2016      1          12           7    10    0.39
# 12      BOS  2016      1          13           6     5    0.71
# 13      BOS  2016      1          14           8     2    0.00
# ...
