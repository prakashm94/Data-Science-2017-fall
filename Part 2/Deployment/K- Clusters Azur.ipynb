# %% [markdown]
# # K-cluster 0

# %%
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'debt_settlement_flag': "N",   
                            'application_type': "Individual",   
                            'fico_range_low': "735",   
                            'fico_range_high': "739",   
                            'emp_length': "10",   
                            'dti': "27.65",   
                            'annual_inc': "24000",   
                            'grade': "B",   
                            'sub_grade': "B2",   
                            'loan_amnt': "5000",   
                            'issue_d': "2011-12-01T00:00:00Z",   
                            'purpose': "credit_card",   
                            'State': "AZ",   
                            'home_ownership': "RENT",   
                            'zip_code': "860",   
                            'policy_code': "1",   
                            'term': "36",   
                            'Year': "2011",   
                            'Month': "12",   
                            'fico': "737",   
                            'approval': "1",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/c2f8dc5126ac4024b08690eda8426a56/services/605482c5d53e4f97b8777bde05394ec9/execute?api-version=2.0&format=swagger'
api_key = 'V6mYCe+WC5G5+5bIp14IRJ091cxZq8DYL2/MYtJCLGKN77QMBDmi6E1aSDNPlWRmniiSwIKH1dwSiAA9ib6UMg==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"debt_settlement_flag":"N","application_type":"Individual","fico_range_low":"735","fico_range_high":"739","emp_length":"10","dti":"27.65","annual_inc":"24000","grade":"B","sub_grade":"B2","loan_amnt":"5000","issue_d":"12/1/2011 12:00:00 AM","purpose":"credit_card","State":"AZ","home_ownership":"RENT","zip_code":"860","policy_code":"1","term":"36","Year":"2011","Month":"12","fico":"737","approval":"1","Scored Label Mean":"10.699","Scored Label Standard Deviation":"0.147000215419282"}]}}'

# %% [markdown]
# # K cluster 1

# %%
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'debt_settlement_flag': "N",   
                            'application_type': "Individual",   
                            'fico_range_low': "735",   
                            'fico_range_high': "739",   
                            'emp_length': "10",   
                            'dti': "27.65",   
                            'annual_inc': "24000",   
                            'grade': "B",   
                            'sub_grade': "B2",   
                            'loan_amnt': "5000",   
                            'issue_d': "2011-12-01T00:00:00Z",   
                            'purpose': "credit_card",   
                            'State': "AZ",   
                            'home_ownership': "RENT",   
                            'zip_code': "860",   
                            'policy_code': "1",   
                            'term': "36",   
                            'Year': "2011",   
                            'Month': "12",   
                            'fico': "737",   
                            'approval': "1",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/c2f8dc5126ac4024b08690eda8426a56/services/212fd57552574c6fa8777f4fa6832e8b/execute?api-version=2.0&format=swagger'
api_key = 's06oiIMbGYKTe31k8T+YUBnXTXn0Ow9FL2L2JD0X1NpBUs9gTLdtdo9CVf+Oej2JiX8ar3JkOd7CNRt5kzcURA==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"debt_settlement_flag":"N","application_type":"Individual","fico_range_low":"735","fico_range_high":"739","emp_length":"10","dti":"27.65","annual_inc":"24000","grade":"B","sub_grade":"B2","loan_amnt":"5000","issue_d":"12/1/2011 12:00:00 AM","purpose":"credit_card","State":"AZ","home_ownership":"RENT","zip_code":"860","policy_code":"1","term":"36","Year":"2011","Month":"12","fico":"737","approval":"1","Scored Label Mean":"10.699","Scored Label Standard Deviation":"0.147000215419282"}]}}'

# %% [markdown]
# # K cluster 2

# %%
 
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'debt_settlement_flag': "N",   
                            'application_type': "Individual",   
                            'fico_range_low': "735",   
                            'fico_range_high': "739",   
                            'emp_length': "10",   
                            'dti': "27.65",   
                            'annual_inc': "24000",   
                            'grade': "B",   
                            'sub_grade': "B2",   
                            'loan_amnt': "5000",   
                            'issue_d': "2011-12-01T00:00:00Z",   
                            'purpose': "credit_card",   
                            'State': "AZ",   
                            'home_ownership': "RENT",   
                            'zip_code': "860",   
                            'policy_code': "1",   
                            'term': "36",   
                            'Year': "2011",   
                            'Month': "12",   
                            'fico': "737",   
                            'approval': "1",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/c2f8dc5126ac4024b08690eda8426a56/services/a0518b16d4a24e93abb5e07c1e1caeb5/execute?api-version=2.0&format=swagger'
api_key = 'NvYLcVmRgj4BO9M94U59mrau4yiwPezdVCvjWqsY2g2r08yEh4X0DMvecov0etITK0au4zNXFKL/MulkusRdWw==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"debt_settlement_flag":"N","application_type":"Individual","fico_range_low":"735","fico_range_high":"739","emp_length":"10","dti":"27.65","annual_inc":"24000","grade":"B","sub_grade":"B2","loan_amnt":"5000","issue_d":"12/1/2011 12:00:00 AM","purpose":"credit_card","State":"AZ","home_ownership":"RENT","zip_code":"860","policy_code":"1","term":"36","Year":"2011","Month":"12","fico":"737","approval":"1","Scored Label Mean":"10.699","Scored Label Standard Deviation":"0.147000215419282"}]}}'

# %% [markdown]
# # K cluster 3

# %%
 
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'debt_settlement_flag': "N",   
                            'application_type': "Individual",   
                            'fico_range_low': "735",   
                            'fico_range_high': "739",   
                            'emp_length': "10",   
                            'dti': "27.65",   
                            'annual_inc': "24000",   
                            'grade': "B",   
                            'sub_grade': "B2",   
                            'loan_amnt': "5000",   
                            'issue_d': "2011-12-01T00:00:00Z",   
                            'purpose': "credit_card",   
                            'State': "AZ",   
                            'home_ownership': "RENT",   
                            'zip_code': "860",   
                            'policy_code': "1",   
                            'term': "36",   
                            'Year': "2011",   
                            'Month': "12",   
                            'fico': "737",   
                            'approval': "1",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/c2f8dc5126ac4024b08690eda8426a56/services/9a07e563a57f4ee89d800e619862aa65/execute?api-version=2.0&format=swagger'
api_key = 'YgyVwIPJXweyHLfi28/jwW3i3a3KHLf8HW56bUVGSSDpTsWD+7xDfxnz4w4SPcfP99j1Lp5OE6szQXmpLS322A==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"debt_settlement_flag":"N","application_type":"Individual","fico_range_low":"735","fico_range_high":"739","emp_length":"10","dti":"27.65","annual_inc":"24000","grade":"B","sub_grade":"B2","loan_amnt":"5000","issue_d":"12/1/2011 12:00:00 AM","purpose":"credit_card","State":"AZ","home_ownership":"RENT","zip_code":"860","policy_code":"1","term":"36","Year":"2011","Month":"12","fico":"737","approval":"1","Scored Label Mean":"10.699","Scored Label Standard Deviation":"0.147000215419282"}]}}'

# %% [markdown]
# # K cluster 4

# %%
 
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'debt_settlement_flag': "N",   
                            'application_type': "Individual",   
                            'fico_range_low': "735",   
                            'fico_range_high': "739",   
                            'emp_length': "10",   
                            'dti': "27.65",   
                            'annual_inc': "24000",   
                            'grade': "B",   
                            'sub_grade': "B2",   
                            'loan_amnt': "5000",   
                            'issue_d': "2011-12-01T00:00:00Z",   
                            'purpose': "credit_card",   
                            'State': "AZ",   
                            'home_ownership': "RENT",   
                            'zip_code': "860",   
                            'policy_code': "1",   
                            'term': "36",   
                            'Year': "2011",   
                            'Month': "12",   
                            'fico': "737",   
                            'approval': "1",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/c2f8dc5126ac4024b08690eda8426a56/services/8d3faa13c38f40babc8ac505a0fa6c6f/execute?api-version=2.0&format=swagger'
api_key = 'aokwGrKclMAzpFKfUKhn3EubxTj7Hmxubz7BeU3oIc+7UVtR4mYf3ysZcbUUT8V40gYyFA7H0nvpS4wuPKI7MA==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"debt_settlement_flag":"N","application_type":"Individual","fico_range_low":"735","fico_range_high":"739","emp_length":"10","dti":"27.65","annual_inc":"24000","grade":"B","sub_grade":"B2","loan_amnt":"5000","issue_d":"12/1/2011 12:00:00 AM","purpose":"credit_card","State":"AZ","home_ownership":"RENT","zip_code":"860","policy_code":"1","term":"36","Year":"2011","Month":"12","fico":"737","approval":"1","Scored Label Mean":"10.699","Scored Label Standard Deviation":"0.147000215419282"}]}}'

# %% [markdown]
# # K cluster 5

# %%
 
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'debt_settlement_flag': "N",   
                            'application_type': "Individual",   
                            'fico_range_low': "735",   
                            'fico_range_high': "739",   
                            'emp_length': "10",   
                            'dti': "27.65",   
                            'annual_inc': "24000",   
                            'grade': "BA",   
                            'sub_grade': "B245",   
                            'loan_amnt': "5000",   
                            'issue_d': "2011-12-01T00:00:00Z",   
                            'purpose': "credit_card",   
                            'State': "AZ",   
                            'home_ownership': "RENT",   
                            'zip_code': "860",   
                            'policy_code': "1",   
                            'term': "36",   
                            'Year': "2011",   
                            'Month': "12",   
                            'fico': "737",   
                            'approval': "1",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/c2f8dc5126ac4024b08690eda8426a56/services/c38f252ebec746b99ed37b0b7e0dd164/execute?api-version=2.0&format=swagger'
api_key = 'Yt/U8UFX4l9/7A9Exj2wPzafKEPgDU+FNoIdfj50FeuiERmkxsKN293xo1UbIO247MfS6bGezCHcMjk0mvx5gA==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"debt_settlement_flag":"N","application_type":"Individual","fico_range_low":"735","fico_range_high":"739","emp_length":"10","dti":"27.65","annual_inc":"24000","grade":"BA","sub_grade":"B245","loan_amnt":"5000","issue_d":"12/1/2011 12:00:00 AM","purpose":"credit_card","State":"AZ","home_ownership":"RENT","zip_code":"860","policy_code":"1","term":"36","Year":"2011","Month":"12","fico":"737","approval":"1","Scored Label Mean":"15.988","Scored Label Standard Deviation":"3.74335091462836"}]}}'

# %% [markdown]
# # K Cluster 7

# %%
import urllib.request
import json

data = {
        "Inputs": {
                "input1":
                [
                    {
                            'debt_settlement_flag': "N",   
                            'application_type': "Individual",   
                            'fico_range_low': "735",   
                            'fico_range_high': "739",   
                            'emp_length': "10",   
                            'dti': "27.65",   
                            'annual_inc': "24000",   
                            'grade': "BB",   
                            'sub_grade': "B67",   
                            'loan_amnt': "5000",   
                            'issue_d': "2011-12-01T00:00:00Z",   
                            'purpose': "credit_card",   
                            'State': "AZ",   
                            'home_ownership': "RENT",   
                            'zip_code': "860",   
                            'policy_code': "1",   
                            'term': "36",   
                            'Year': "2011",   
                            'Month': "12",   
                            'fico': "737",   
                            'approval': "1",   
                    }
                ],
        },
    "GlobalParameters":  {
    }
}

body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/c2f8dc5126ac4024b08690eda8426a56/services/11904d20378745bf9cad7d40121722c3/execute?api-version=2.0&format=swagger'
api_key = '6T6QBFiJOAAiEEQxWoa/Z69I4uaL0wwpfUpKZecYooBXG2TX+iZuKwq3+pWH8r9sPkb8w0G4TRUO+cGMt8pA5A==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":[{"debt_settlement_flag":"N","application_type":"Individual","fico_range_low":"735","fico_range_high":"739","emp_length":"10","dti":"27.65","annual_inc":"24000","grade":"BB","sub_grade":"B67","loan_amnt":"5000","issue_d":"12/1/2011 12:00:00 AM","purpose":"credit_card","State":"AZ","home_ownership":"RENT","zip_code":"860","policy_code":"1","term":"36","Year":"2011","Month":"12","fico":"737","approval":"1","Scored Label Mean":"15.988","Scored Label Standard Deviation":"3.74335091462836"}]}}'
